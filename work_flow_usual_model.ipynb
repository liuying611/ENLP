# %%
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from xgboost.sklearn import XGBClassifier
from sklearn import metrics
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.base import clone
from sklearn.preprocessing import label_binarize
from scipy import interp
from sklearn.metrics import roc_curve, auc 
# import kfold
from sklearn.model_selection import KFold
# import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# import LabelEncoder
from sklearn.preprocessing import LabelEncoder
#import MultinomialNB
from sklearn.naive_bayes import MultinomialNB
# import Pipeline
from sklearn.pipeline import Pipeline
# import Validate
from sklearn.model_selection import cross_validate
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
def train_predict_model(fpath, classifier, vectorizer, confusion_mtx = False):
    # build model
    df = pd.read_csv(fpath)
    le = LabelEncoder()
    df['label'] = le.fit_transform(df['category'])
    X_train, X_test, y_train, y_test = train_test_split(df.text, df.label, test_size=0.2, random_state=42)
    X_train = vectorizer.fit_transform(X_train)
    classifier.fit(X_train, y_train)
    # predict using model
    X_test = vectorizer.transform(X_test)
    predictions = classifier.predict(X_test) 

    if confusion_mtx:
        plot_confusion_matrix(y_test, predictions, le)
    accuracy = metrics.accuracy_score(y_test, predictions)
    return accuracy, metrics.classification_report(y_test, predictions, target_names=le.classes_)

def plot_confusion_matrix(y_true, y_pred, le):
    #y_true = le.inverse_transform(y_true)
    #y_pred = le.inverse_transform(y_pred)

    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.tight_layout()
    plt.xlabel('True class')
    plt.ylabel('Predicted class')
    classes = le.classes_
    plt.xticks(range(10), classes, rotation=90)
    plt.yticks(range(10), classes, rotation=0)
    plt.tight_layout()
    plt.show()

# %%
fpaths = [
          #'./data/df_all_category_nobalance.csv', # kernel died
          #'./data/df_10_category_nobalance.csv', # kernel died
          './data/df_10_category_balance.csv',
          './data/df_10_category_balance_60k.csv',
          './data/df_10_category_balance_30k.csv',
          './data/df_10_category_balance_10k.csv',
          './data/df_10_category_balance_3k.csv']
fpaths = fpaths[::-1]
names = ['3k', '10k', '30k', '60k', '100k']

models = [LogisticRegression(), XGBClassifier(), LinearSVC(), RidgeClassifier(), MultinomialNB()]
accuracy_list = {}
report_list = {}
for i, file in enumerate(fpaths):
    print(f'Reading file {file} ...')
    accuracy_list[names[i]] = {}
    report_list[names[i]] = {}
    for model in models:
        # print the model name
        model_name = str(model).split("(")[0]
        print(f'{model_name}:')
        vectorizer = TfidfVectorizer(
            max_df=0.8,  # Ignore terms that appear in more than 80% of documents
            min_df=2,    # Ignore terms that appear in fewer than 2 documents
            ngram_range=(1,2)  # Use both unigrams and bigrams
        )
        accuracy, report = train_predict_model(file, model, vectorizer, confusion_mtx = True)
        accuracy_list[names[i]][model_name] = accuracy
        report_list[names[i]][model_name] = report
# Out:
# Reading file ./data/df_10_category_balance_3k.csv ...
# LogisticRegression:
# XGBClassifier:
# LinearSVC:
# RidgeClassifier:
# MultinomialNB:
# Reading file ./data/df_10_category_balance_10k.csv ...
# LogisticRegression:
# XGBClassifier:
# LinearSVC:
# RidgeClassifier:
# MultinomialNB:
# Reading file ./data/df_10_category_balance_30k.csv ...
# LogisticRegression:
# /Users/yaoyao/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# XGBClassifier:
# LinearSVC:
# RidgeClassifier:
# MultinomialNB:
# Reading file ./data/df_10_category_balance_60k.csv ...
# LogisticRegression:
# /Users/yaoyao/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# XGBClassifier:
# LinearSVC:
# RidgeClassifier:
# MultinomialNB:
# Reading file ./data/df_10_category_balance.csv ...
# LogisticRegression:
# /Users/yaoyao/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# XGBClassifier:
# LinearSVC:
# RidgeClassifier:
# MultinomialNB:

# %%
models_names = ['LogisticRegression', 'XGBClassifier', 'LinearSVC', 'RidgeClassifier', 'MultinomialNB']

# %%
acc_lr_list = list(map(lambda x:x*100, [accuracy_list['3k']['LogisticRegression'], accuracy_list['10k']['LogisticRegression'], accuracy_list['30k']['LogisticRegression'], accuracy_list['60k']['LogisticRegression'], accuracy_list['100k']['LogisticRegression']]))
acc_xgb_list = list(map(lambda x:x*100, [accuracy_list['3k']['XGBClassifier'], accuracy_list['10k']['XGBClassifier'], accuracy_list['30k']['XGBClassifier'], accuracy_list['60k']['XGBClassifier'], accuracy_list['100k']['XGBClassifier']]))
acc_svc_list = list(map(lambda x:x*100, [accuracy_list['3k']['LinearSVC'], accuracy_list['10k']['LinearSVC'], accuracy_list['30k']['LinearSVC'], accuracy_list['60k']['LinearSVC'], accuracy_list['100k']['LinearSVC']]))
acc_ridge_list = list(map(lambda x:x*100, [accuracy_list['3k']['RidgeClassifier'], accuracy_list['10k']['RidgeClassifier'], accuracy_list['30k']['RidgeClassifier'], accuracy_list['60k']['RidgeClassifier'], accuracy_list['100k']['RidgeClassifier']]))
acc_mnb_list = list(map(lambda x:x*100, [accuracy_list['3k']['MultinomialNB'], accuracy_list['10k']['MultinomialNB'], accuracy_list['30k']['MultinomialNB'], accuracy_list['60k']['MultinomialNB'], accuracy_list['100k']['MultinomialNB']]))
acc_list = [acc_lr_list, acc_xgb_list, acc_svc_list, acc_ridge_list, acc_mnb_list]

# %%
plt.figure(figsize=(10, 3))
for i, acc in enumerate(acc_list):
    plt.plot(names, acc, label=models_names[i])
plt.legend()
plt.ylabel('Accuracy (%)')
plt.grid()
plt.show()

# %%
accuracy_list
# Out:
# {'3k': {'LogisticRegression': 0.625,
#   'XGBClassifier': 0.5683333333333334,
#   'LinearSVC': 0.6516666666666666,
#   'RidgeClassifier': 0.66,
#   'MultinomialNB': 0.515},
#  '10k': {'LogisticRegression': 0.6805,
#   'XGBClassifier': 0.642,
#   'LinearSVC': 0.6895,
#   'RidgeClassifier': 0.6995,
#   'MultinomialNB': 0.6255},
#  '30k': {'LogisticRegression': 0.7393333333333333,
#   'XGBClassifier': 0.7063333333333334,
#   'LinearSVC': 0.7533333333333333,
#   'RidgeClassifier': 0.7591666666666667,
#   'MultinomialNB': 0.679},
#  '60k': {'LogisticRegression': 0.7686666666666667,
#   'XGBClassifier': 0.7228333333333333,
#   'LinearSVC': 0.779,
#   'RidgeClassifier': 0.782,
#   'MultinomialNB': 0.7096666666666667},
#  '100k': {'LogisticRegression': 0.7823863932801168,
#   'XGBClassifier': 0.733239421923097,
#   'LinearSVC': 0.7946470496165284,
#   'RidgeClassifier': 0.7977774299577398,
#   'MultinomialNB': 0.7272916992747952}}

# %%
names
# Out:
# ['3k', '10k', '30k', '60k', '100k']

# %%
x = names

# %%
report_list
# Out:
# {'3k': {'LogisticRegression': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       1.00      0.14      0.24        43\n      ENTERTAINMENT       0.57      0.43      0.49        54\n       FOOD & DRINK       0.93      0.61      0.74        41\n      GROUPS VOICES       0.76      0.52      0.61        66\n          PARENTING       0.71      0.80      0.75        81\n           POLITICS       0.53      0.74      0.61        68\n     STYLE & BEAUTY       0.84      0.71      0.77        66\n             TRAVEL       0.71      0.71      0.71        58\n           WELLNESS       0.38      0.82      0.51        65\n         WORLD NEWS       0.78      0.53      0.63        58\n\n           accuracy                           0.62       600\n          macro avg       0.72      0.60      0.61       600\n       weighted avg       0.70      0.62      0.62       600\n',
#   'XGBClassifier': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.52      0.37      0.43        43\n      ENTERTAINMENT       0.41      0.48      0.44        54\n       FOOD & DRINK       0.57      0.68      0.62        41\n      GROUPS VOICES       0.60      0.55      0.57        66\n          PARENTING       0.76      0.72      0.74        81\n           POLITICS       0.53      0.57      0.55        68\n     STYLE & BEAUTY       0.75      0.64      0.69        66\n             TRAVEL       0.49      0.41      0.45        58\n           WELLNESS       0.47      0.66      0.55        65\n         WORLD NEWS       0.59      0.50      0.54        58\n\n           accuracy                           0.57       600\n          macro avg       0.57      0.56      0.56       600\n       weighted avg       0.58      0.57      0.57       600\n',
#   'LinearSVC': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.82      0.42      0.55        43\n      ENTERTAINMENT       0.50      0.50      0.50        54\n       FOOD & DRINK       0.76      0.68      0.72        41\n      GROUPS VOICES       0.73      0.61      0.66        66\n          PARENTING       0.75      0.75      0.75        81\n           POLITICS       0.52      0.66      0.58        68\n     STYLE & BEAUTY       0.71      0.71      0.71        66\n             TRAVEL       0.62      0.74      0.68        58\n           WELLNESS       0.56      0.69      0.62        65\n         WORLD NEWS       0.74      0.64      0.69        58\n\n           accuracy                           0.65       600\n          macro avg       0.67      0.64      0.65       600\n       weighted avg       0.67      0.65      0.65       600\n',
#   'RidgeClassifier': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.75      0.35      0.48        43\n      ENTERTAINMENT       0.59      0.50      0.54        54\n       FOOD & DRINK       0.79      0.66      0.72        41\n      GROUPS VOICES       0.72      0.59      0.65        66\n          PARENTING       0.74      0.78      0.76        81\n           POLITICS       0.57      0.71      0.63        68\n     STYLE & BEAUTY       0.74      0.73      0.73        66\n             TRAVEL       0.64      0.76      0.69        58\n           WELLNESS       0.53      0.74      0.62        65\n         WORLD NEWS       0.71      0.64      0.67        58\n\n           accuracy                           0.66       600\n          macro avg       0.68      0.64      0.65       600\n       weighted avg       0.67      0.66      0.66       600\n',
#   'MultinomialNB': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       1.00      0.05      0.09        43\n      ENTERTAINMENT       0.83      0.19      0.30        54\n       FOOD & DRINK       0.93      0.34      0.50        41\n      GROUPS VOICES       0.83      0.30      0.44        66\n          PARENTING       0.50      0.84      0.63        81\n           POLITICS       0.46      0.75      0.57        68\n     STYLE & BEAUTY       0.84      0.73      0.78        66\n             TRAVEL       0.78      0.43      0.56        58\n           WELLNESS       0.28      0.82      0.41        65\n         WORLD NEWS       0.90      0.31      0.46        58\n\n           accuracy                           0.52       600\n          macro avg       0.74      0.47      0.47       600\n       weighted avg       0.71      0.52      0.49       600\n'},
#  '10k': {'LogisticRegression': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.79      0.43      0.56       135\n      ENTERTAINMENT       0.62      0.49      0.55       147\n       FOOD & DRINK       0.81      0.68      0.74       154\n      GROUPS VOICES       0.62      0.53      0.57       217\n          PARENTING       0.73      0.75      0.74       265\n           POLITICS       0.65      0.71      0.68       248\n     STYLE & BEAUTY       0.76      0.83      0.80       230\n             TRAVEL       0.69      0.73      0.71       198\n           WELLNESS       0.57      0.80      0.67       255\n         WORLD NEWS       0.72      0.64      0.68       151\n\n           accuracy                           0.68      2000\n          macro avg       0.70      0.66      0.67      2000\n       weighted avg       0.69      0.68      0.68      2000\n',
#   'XGBClassifier': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.60      0.50      0.54       135\n      ENTERTAINMENT       0.48      0.44      0.46       147\n       FOOD & DRINK       0.76      0.72      0.74       154\n      GROUPS VOICES       0.58      0.52      0.55       217\n          PARENTING       0.72      0.75      0.74       265\n           POLITICS       0.62      0.61      0.62       248\n     STYLE & BEAUTY       0.74      0.79      0.77       230\n             TRAVEL       0.66      0.65      0.65       198\n           WELLNESS       0.58      0.68      0.63       255\n         WORLD NEWS       0.61      0.61      0.61       151\n\n           accuracy                           0.64      2000\n          macro avg       0.64      0.63      0.63      2000\n       weighted avg       0.64      0.64      0.64      2000\n',
#   'LinearSVC': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.67      0.56      0.61       135\n      ENTERTAINMENT       0.57      0.56      0.56       147\n       FOOD & DRINK       0.78      0.78      0.78       154\n      GROUPS VOICES       0.66      0.52      0.58       217\n          PARENTING       0.74      0.75      0.74       265\n           POLITICS       0.66      0.68      0.67       248\n     STYLE & BEAUTY       0.78      0.82      0.80       230\n             TRAVEL       0.68      0.75      0.72       198\n           WELLNESS       0.63      0.71      0.67       255\n         WORLD NEWS       0.69      0.69      0.69       151\n\n           accuracy                           0.69      2000\n          macro avg       0.69      0.68      0.68      2000\n       weighted avg       0.69      0.69      0.69      2000\n',
#   'RidgeClassifier': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.69      0.52      0.59       135\n      ENTERTAINMENT       0.57      0.53      0.55       147\n       FOOD & DRINK       0.77      0.77      0.77       154\n      GROUPS VOICES       0.69      0.54      0.61       217\n          PARENTING       0.76      0.77      0.76       265\n           POLITICS       0.66      0.71      0.68       248\n     STYLE & BEAUTY       0.78      0.83      0.80       230\n             TRAVEL       0.70      0.76      0.73       198\n           WELLNESS       0.65      0.75      0.69       255\n         WORLD NEWS       0.71      0.69      0.70       151\n\n           accuracy                           0.70      2000\n          macro avg       0.70      0.69      0.69      2000\n       weighted avg       0.70      0.70      0.70      2000\n',
#   'MultinomialNB': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.96      0.20      0.33       135\n      ENTERTAINMENT       0.85      0.24      0.37       147\n       FOOD & DRINK       0.91      0.44      0.59       154\n      GROUPS VOICES       0.64      0.51      0.57       217\n          PARENTING       0.58      0.79      0.67       265\n           POLITICS       0.57      0.77      0.66       248\n     STYLE & BEAUTY       0.76      0.81      0.78       230\n             TRAVEL       0.70      0.67      0.69       198\n           WELLNESS       0.47      0.86      0.60       255\n         WORLD NEWS       0.84      0.47      0.60       151\n\n           accuracy                           0.63      2000\n          macro avg       0.73      0.58      0.59      2000\n       weighted avg       0.69      0.63      0.61      2000\n'},
#  '30k': {'LogisticRegression': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.72      0.53      0.61       426\n      ENTERTAINMENT       0.70      0.61      0.65       499\n       FOOD & DRINK       0.85      0.78      0.81       440\n      GROUPS VOICES       0.68      0.60      0.64       610\n          PARENTING       0.75      0.81      0.78       708\n           POLITICS       0.72      0.79      0.75       765\n     STYLE & BEAUTY       0.83      0.83      0.83       670\n             TRAVEL       0.79      0.76      0.78       578\n           WELLNESS       0.65      0.84      0.73       791\n         WORLD NEWS       0.79      0.72      0.75       513\n\n           accuracy                           0.74      6000\n          macro avg       0.75      0.73      0.73      6000\n       weighted avg       0.74      0.74      0.74      6000\n',
#   'XGBClassifier': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.69      0.55      0.61       426\n      ENTERTAINMENT       0.65      0.56      0.60       499\n       FOOD & DRINK       0.78      0.77      0.77       440\n      GROUPS VOICES       0.71      0.56      0.63       610\n          PARENTING       0.74      0.81      0.78       708\n           POLITICS       0.71      0.75      0.73       765\n     STYLE & BEAUTY       0.78      0.81      0.79       670\n             TRAVEL       0.73      0.68      0.71       578\n           WELLNESS       0.60      0.78      0.68       791\n         WORLD NEWS       0.73      0.68      0.70       513\n\n           accuracy                           0.71      6000\n          macro avg       0.71      0.69      0.70      6000\n       weighted avg       0.71      0.71      0.70      6000\n',
#   'LinearSVC': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.66      0.56      0.60       426\n      ENTERTAINMENT       0.67      0.63      0.65       499\n       FOOD & DRINK       0.85      0.82      0.84       440\n      GROUPS VOICES       0.68      0.62      0.65       610\n          PARENTING       0.76      0.82      0.78       708\n           POLITICS       0.74      0.78      0.76       765\n     STYLE & BEAUTY       0.85      0.84      0.85       670\n             TRAVEL       0.80      0.81      0.81       578\n           WELLNESS       0.73      0.81      0.77       791\n         WORLD NEWS       0.77      0.74      0.75       513\n\n           accuracy                           0.75      6000\n          macro avg       0.75      0.74      0.75      6000\n       weighted avg       0.75      0.75      0.75      6000\n',
#   'RidgeClassifier': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.70      0.56      0.62       426\n      ENTERTAINMENT       0.70      0.62      0.66       499\n       FOOD & DRINK       0.84      0.83      0.83       440\n      GROUPS VOICES       0.71      0.62      0.66       610\n          PARENTING       0.75      0.82      0.79       708\n           POLITICS       0.74      0.80      0.77       765\n     STYLE & BEAUTY       0.85      0.86      0.86       670\n             TRAVEL       0.79      0.81      0.80       578\n           WELLNESS       0.72      0.82      0.77       791\n         WORLD NEWS       0.78      0.74      0.76       513\n\n           accuracy                           0.76      6000\n          macro avg       0.76      0.75      0.75      6000\n       weighted avg       0.76      0.76      0.76      6000\n',
#   'MultinomialNB': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.93      0.19      0.32       426\n      ENTERTAINMENT       0.87      0.37      0.52       499\n       FOOD & DRINK       0.92      0.55      0.69       440\n      GROUPS VOICES       0.67      0.57      0.62       610\n          PARENTING       0.59      0.84      0.70       708\n           POLITICS       0.63      0.86      0.73       765\n     STYLE & BEAUTY       0.79      0.82      0.81       670\n             TRAVEL       0.79      0.72      0.75       578\n           WELLNESS       0.53      0.88      0.66       791\n         WORLD NEWS       0.89      0.59      0.71       513\n\n           accuracy                           0.68      6000\n          macro avg       0.76      0.64      0.65      6000\n       weighted avg       0.74      0.68      0.66      6000\n'},
#  '60k': {'LogisticRegression': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.74      0.59      0.66       831\n      ENTERTAINMENT       0.70      0.63      0.67       946\n       FOOD & DRINK       0.84      0.80      0.82       860\n      GROUPS VOICES       0.76      0.67      0.71      1279\n          PARENTING       0.75      0.82      0.79      1496\n           POLITICS       0.76      0.79      0.77      1435\n     STYLE & BEAUTY       0.86      0.86      0.86      1335\n             TRAVEL       0.80      0.82      0.81      1206\n           WELLNESS       0.69      0.83      0.75      1578\n         WORLD NEWS       0.82      0.77      0.80      1034\n\n           accuracy                           0.77     12000\n          macro avg       0.77      0.76      0.76     12000\n       weighted avg       0.77      0.77      0.77     12000\n',
#   'XGBClassifier': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.68      0.58      0.63       831\n      ENTERTAINMENT       0.64      0.60      0.62       946\n       FOOD & DRINK       0.78      0.78      0.78       860\n      GROUPS VOICES       0.72      0.60      0.66      1279\n          PARENTING       0.75      0.79      0.77      1496\n           POLITICS       0.75      0.74      0.75      1435\n     STYLE & BEAUTY       0.80      0.81      0.81      1335\n             TRAVEL       0.77      0.73      0.75      1206\n           WELLNESS       0.61      0.78      0.69      1578\n         WORLD NEWS       0.77      0.70      0.73      1034\n\n           accuracy                           0.72     12000\n          macro avg       0.73      0.71      0.72     12000\n       weighted avg       0.73      0.72      0.72     12000\n',
#   'LinearSVC': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.73      0.64      0.68       831\n      ENTERTAINMENT       0.72      0.66      0.69       946\n       FOOD & DRINK       0.82      0.82      0.82       860\n      GROUPS VOICES       0.77      0.70      0.73      1279\n          PARENTING       0.76      0.81      0.78      1496\n           POLITICS       0.78      0.78      0.78      1435\n     STYLE & BEAUTY       0.87      0.88      0.87      1335\n             TRAVEL       0.80      0.83      0.81      1206\n           WELLNESS       0.73      0.81      0.77      1578\n         WORLD NEWS       0.82      0.80      0.81      1034\n\n           accuracy                           0.78     12000\n          macro avg       0.78      0.77      0.77     12000\n       weighted avg       0.78      0.78      0.78     12000\n',
#   'RidgeClassifier': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.75      0.64      0.69       831\n      ENTERTAINMENT       0.73      0.65      0.69       946\n       FOOD & DRINK       0.81      0.83      0.82       860\n      GROUPS VOICES       0.78      0.68      0.73      1279\n          PARENTING       0.76      0.81      0.79      1496\n           POLITICS       0.78      0.79      0.78      1435\n     STYLE & BEAUTY       0.86      0.87      0.87      1335\n             TRAVEL       0.80      0.84      0.82      1206\n           WELLNESS       0.72      0.82      0.77      1578\n         WORLD NEWS       0.83      0.80      0.82      1034\n\n           accuracy                           0.78     12000\n          macro avg       0.78      0.77      0.78     12000\n       weighted avg       0.78      0.78      0.78     12000\n',
#   'MultinomialNB': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.90      0.29      0.44       831\n      ENTERTAINMENT       0.86      0.38      0.53       946\n       FOOD & DRINK       0.91      0.57      0.70       860\n      GROUPS VOICES       0.72      0.65      0.68      1279\n          PARENTING       0.63      0.83      0.72      1496\n           POLITICS       0.66      0.85      0.74      1435\n     STYLE & BEAUTY       0.83      0.84      0.84      1335\n             TRAVEL       0.81      0.77      0.79      1206\n           WELLNESS       0.56      0.88      0.68      1578\n         WORLD NEWS       0.87      0.66      0.75      1034\n\n           accuracy                           0.71     12000\n          macro avg       0.77      0.67      0.69     12000\n       weighted avg       0.75      0.71      0.70     12000\n'},
#  '100k': {'LogisticRegression': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.74      0.66      0.70      1282\n      ENTERTAINMENT       0.74      0.67      0.70      1559\n       FOOD & DRINK       0.83      0.81      0.82      1369\n      GROUPS VOICES       0.77      0.68      0.72      2049\n          PARENTING       0.77      0.81      0.79      2376\n           POLITICS       0.77      0.78      0.78      2300\n     STYLE & BEAUTY       0.87      0.88      0.87      2166\n             TRAVEL       0.82      0.82      0.82      1886\n           WELLNESS       0.73      0.83      0.77      2567\n         WORLD NEWS       0.81      0.79      0.80      1613\n\n           accuracy                           0.78     19167\n          macro avg       0.78      0.77      0.78     19167\n       weighted avg       0.78      0.78      0.78     19167\n',
#   'XGBClassifier': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.68      0.63      0.66      1282\n      ENTERTAINMENT       0.68      0.60      0.64      1559\n       FOOD & DRINK       0.79      0.80      0.79      1369\n      GROUPS VOICES       0.76      0.61      0.67      2049\n          PARENTING       0.75      0.80      0.78      2376\n           POLITICS       0.74      0.74      0.74      2300\n     STYLE & BEAUTY       0.81      0.83      0.82      2166\n             TRAVEL       0.78      0.73      0.75      1886\n           WELLNESS       0.64      0.79      0.71      2567\n         WORLD NEWS       0.74      0.70      0.72      1613\n\n           accuracy                           0.73     19167\n          macro avg       0.74      0.72      0.73     19167\n       weighted avg       0.74      0.73      0.73     19167\n',
#   'LinearSVC': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.74      0.69      0.72      1282\n      ENTERTAINMENT       0.76      0.68      0.72      1559\n       FOOD & DRINK       0.84      0.84      0.84      1369\n      GROUPS VOICES       0.78      0.71      0.74      2049\n          PARENTING       0.78      0.83      0.80      2376\n           POLITICS       0.77      0.79      0.78      2300\n     STYLE & BEAUTY       0.87      0.89      0.88      2166\n             TRAVEL       0.83      0.84      0.84      1886\n           WELLNESS       0.76      0.81      0.79      2567\n         WORLD NEWS       0.81      0.81      0.81      1613\n\n           accuracy                           0.79     19167\n          macro avg       0.79      0.79      0.79     19167\n       weighted avg       0.79      0.79      0.79     19167\n',
#   'RidgeClassifier': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.77      0.70      0.73      1282\n      ENTERTAINMENT       0.76      0.67      0.72      1559\n       FOOD & DRINK       0.83      0.85      0.84      1369\n      GROUPS VOICES       0.79      0.70      0.74      2049\n          PARENTING       0.78      0.83      0.80      2376\n           POLITICS       0.78      0.79      0.78      2300\n     STYLE & BEAUTY       0.87      0.89      0.88      2166\n             TRAVEL       0.83      0.84      0.84      1886\n           WELLNESS       0.76      0.83      0.79      2567\n         WORLD NEWS       0.81      0.81      0.81      1613\n\n           accuracy                           0.80     19167\n          macro avg       0.80      0.79      0.79     19167\n       weighted avg       0.80      0.80      0.80     19167\n',
#   'MultinomialNB': '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       0.89      0.36      0.51      1282\n      ENTERTAINMENT       0.89      0.41      0.56      1559\n       FOOD & DRINK       0.90      0.64      0.75      1369\n      GROUPS VOICES       0.71      0.67      0.69      2049\n          PARENTING       0.65      0.82      0.72      2376\n           POLITICS       0.67      0.84      0.74      2300\n     STYLE & BEAUTY       0.82      0.86      0.84      2166\n             TRAVEL       0.83      0.78      0.81      1886\n           WELLNESS       0.59      0.88      0.71      2567\n         WORLD NEWS       0.87      0.70      0.77      1613\n\n           accuracy                           0.73     19167\n          macro avg       0.78      0.70      0.71     19167\n       weighted avg       0.76      0.73      0.72     19167\n'}}

# %%
#print(report_list['100k']['LogisticRegression'])
precision_100k_lr = [74, 74, 83, 77, 77, 77, 87, 82, 73, 81, 78]
precision_100k_xgb = [68, 68, 79, 76, 75, 74, 81, 78, 64, 74, 73]
precision_100k_svc = [74, 76, 84, 78, 78, 77, 87, 83, 76, 81, 79]
precision_100k_rc = [77, 76, 83, 79, 78, 78, 87, 83, 76, 81, 80]
precision_100k_mnb = [89, 89, 90, 71, 65, 67, 82, 83, 59, 87, 73]
classes = ['BUSINESS & FINANCES', 'ENTERTAINMENT', 'FOOD & DRINK', 'GROUPS VOICES', 'PARENTING', 'POLITICS', 'STYLE & BEAUTY', 'TRAVEL', 'WELLNESS', 'WORLD NEWS', 'avg_acc' ]

# %%
accuracy_list
# Out:
# {'3k': {'LogisticRegression': 0.625,
#   'XGBClassifier': 0.5683333333333334,
#   'LinearSVC': 0.6516666666666666,
#   'RidgeClassifier': 0.66,
#   'MultinomialNB': 0.515},
#  '10k': {'LogisticRegression': 0.6805,
#   'XGBClassifier': 0.642,
#   'LinearSVC': 0.6895,
#   'RidgeClassifier': 0.6995,
#   'MultinomialNB': 0.6255},
#  '30k': {'LogisticRegression': 0.7393333333333333,
#   'XGBClassifier': 0.7063333333333334,
#   'LinearSVC': 0.7533333333333333,
#   'RidgeClassifier': 0.7591666666666667,
#   'MultinomialNB': 0.679},
#  '60k': {'LogisticRegression': 0.7686666666666667,
#   'XGBClassifier': 0.7228333333333333,
#   'LinearSVC': 0.779,
#   'RidgeClassifier': 0.782,
#   'MultinomialNB': 0.7096666666666667},
#  '100k': {'LogisticRegression': 0.7823863932801168,
#   'XGBClassifier': 0.733239421923097,
#   'LinearSVC': 0.7946470496165284,
#   'RidgeClassifier': 0.7977774299577398,
#   'MultinomialNB': 0.7272916992747952}}

# %%
x = classes
plt.figure(figsize=(10, 3))
plt.plot(x, precision_100k_lr, label='LogisticRegression')
plt.plot(x, precision_100k_xgb, label='XGBClassifier')
plt.plot(x, precision_100k_svc, label='LinearSVC')
plt.plot(x, precision_100k_rc, label='RidgeClassifier')
plt.plot(x, precision_100k_mnb, label='MultinomialNB')
# make the legend outside the plot
plt.legend(loc='lower left', borderaxespad=0.)
plt.ylabel('Precision (%)')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %%
# plot the precision of each model in the same figure, x-axis is the model name, y-axis is the precision
x = report_list['3k'].keys()
y = [report_list['3k'][key]['precision'] for key in x]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> # plot the precision of each model in the same figure, x-axis is the model name, y-axis is the precision
#       <a href='vscode-notebook-cell:/Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb#X51sZmlsZQ%3D%3D?line=1'>2</a> x = report_list['3k'].keys()
# ----> <a href='vscode-notebook-cell:/Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb#X51sZmlsZQ%3D%3D?line=2'>3</a> y = [report_list['3k'][key]['precision'] for key in x]
#
# /Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb Cell 5 line 3
#       <a href='vscode-notebook-cell:/Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> # plot the precision of each model in the same figure, x-axis is the model name, y-axis is the precision
#       <a href='vscode-notebook-cell:/Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb#X51sZmlsZQ%3D%3D?line=1'>2</a> x = report_list['3k'].keys()
# ----> <a href='vscode-notebook-cell:/Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb#X51sZmlsZQ%3D%3D?line=2'>3</a> y = [report_list['3k'][key]['precision'] for key in x]
#
# TypeError: string indices must be integers

# %%
report_list['3k']['LogisticRegression']
# Out:
# '                     precision    recall  f1-score   support\n\nBUSINESS & FINANCES       1.00      0.14      0.24        43\n      ENTERTAINMENT       0.57      0.43      0.49        54\n       FOOD & DRINK       0.93      0.61      0.74        41\n      GROUPS VOICES       0.76      0.52      0.61        66\n          PARENTING       0.71      0.80      0.75        81\n           POLITICS       0.53      0.74      0.61        68\n     STYLE & BEAUTY       0.84      0.71      0.77        66\n             TRAVEL       0.71      0.71      0.71        58\n           WELLNESS       0.38      0.82      0.51        65\n         WORLD NEWS       0.78      0.53      0.63        58\n\n           accuracy                           0.62       600\n          macro avg       0.72      0.60      0.61       600\n       weighted avg       0.70      0.62      0.62       600\n'

# %%
print(report_list['3k']['LogisticRegression'])
# Out:
#                      precision    recall  f1-score   support
#
# BUSINESS & FINANCES       1.00      0.14      0.24        43
#       ENTERTAINMENT       0.57      0.43      0.49        54
#        FOOD & DRINK       0.93      0.61      0.74        41
#       GROUPS VOICES       0.76      0.52      0.61        66
#           PARENTING       0.71      0.80      0.75        81
#            POLITICS       0.53      0.74      0.61        68
#      STYLE & BEAUTY       0.84      0.71      0.77        66
#              TRAVEL       0.71      0.71      0.71        58
#            WELLNESS       0.38      0.82      0.51        65
#          WORLD NEWS       0.78      0.53      0.63        58
#
#            accuracy                           0.62       600
#           macro avg       0.72      0.60      0.61       600
#        weighted avg       0.70      0.62      0.62       600

# %%
3k_logistic

# %%
models = [LogisticRegression(), XGBClassifier(), LinearSVC(), RidgeClassifier(), MultinomialNB()]
for model in models:
    print(f'{str(model).split("(")[0]}:')
# Out:
# LogisticRegression:
# XGBClassifier:
# LinearSVC:
# RidgeClassifier:
# MultinomialNB:

# %%
model = LogisticRegression()
vectorizer = TfidfVectorizer(
    max_df=0.8,  # Ignore terms that appear in more than 80% of documents
    min_df=2,    # Ignore terms that appear in fewer than 2 documents
    ngram_range=(1,2)  # Use both unigrams and bigrams
)
fpath = './data/df_10_category_balance_3k.csv'
accuracy, report = train_predict_model(fpath, model, vectorizer, confusion_mtx = True)
print(report)
# Out:
# Classification Report:
# ['BUSINESS & FINANCES' 'ENTERTAINMENT' 'FOOD & DRINK' 'GROUPS VOICES'
#  'PARENTING' 'POLITICS' 'STYLE & BEAUTY' 'TRAVEL' 'WELLNESS' 'WORLD NEWS']
#                      precision    recall  f1-score   support
#
# BUSINESS & FINANCES       1.00      0.14      0.24        43
#       ENTERTAINMENT       0.57      0.43      0.49        54
#        FOOD & DRINK       0.93      0.61      0.74        41
#       GROUPS VOICES       0.76      0.52      0.61        66
#           PARENTING       0.71      0.80      0.75        81
#            POLITICS       0.53      0.74      0.61        68
#      STYLE & BEAUTY       0.84      0.71      0.77        66
#              TRAVEL       0.71      0.71      0.71        58
#            WELLNESS       0.38      0.82      0.51        65
#          WORLD NEWS       0.78      0.53      0.63        58
#
#            accuracy                           0.62       600
#           macro avg       0.72      0.60      0.61       600
#        weighted avg       0.70      0.62      0.62       600

# %%
df = pd.read_csv('./data/df_10_category_balance_3k.csv')
df.head()
# Out:
#         category                                               text      sa
# 0   FOOD & DRINK  dessert recipe raisin lover hater steer clear ... -0.3182
# 1  GROUPS VOICES  trump different response orlando vega massacre... -0.3612
# 2       POLITICS  friday talking point double standard hypocrisy...  0.6597
# 3   FOOD & DRINK  postthanksgiving detox diet overindulging than...  0.1280
# 4       WELLNESS  6 quote encourage march march stress strain co...  0.0772

# %%
df['label'] = LabelEncoder().fit_transform(df['category'])

# %%
X_train, X_test, y_train, y_test = train_test_split(df.text, df.label, test_size=0.2, random_state=42)

# %%
folds = KFold(n_splits = 5, shuffle = True, random_state = 1)

# %%
vect = TfidfVectorizer()
vect.fit(X_train)
# Out:
# TfidfVectorizer()

# %%
NB = MultinomialNB()
Ridge = RidgeClassifier()
XGB = XGBClassifier(objective = 'multi:softprob')
def fit_model(clf , name):
    pipe = Pipeline([
    ('vectorize', vect),
    (name, clf)])
    result = cross_validate(pipe, X_train, y_train, cv = folds, return_train_score=True,scoring = ('accuracy', 
                                                                                       'f1_weighted', 
                                                                                       'precision_weighted', 
                                                                                       'recall_weighted'))
    return result

# %%
bayes = fit_model(NB, 'NB')
ridge = fit_model(Ridge, 'Ridge')
xgb = fit_model(XGB, 'XGB')
b = pd.DataFrame.from_dict(bayes)
b['model'] = ["NB","NB","NB","NB","NB"]
r = pd.DataFrame.from_dict(ridge)
r['model'] = ["Ridge","Ridge","Ridge","Ridge","Ridge"]
x = pd.DataFrame.from_dict(xgb)
x['model'] = ["XGB","XGB","XGB","XGB","XGB"]

results = pd.concat([b,r,x])
# Out:
# /Users/yaoyao/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/yaoyao/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/yaoyao/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/yaoyao/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/yaoyao/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
results.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> results.head()
#
# NameError: name 'results' is not defined

# %%
models_eval = results.groupby("model")

# %%
models_eval.head()

# %%
means = models_eval.mean()
sd = models_eval.std()

# %%
means.head()
# Out:
#        fit_time  score_time  test_accuracy  train_accuracy  test_f1_weighted  \
# model
# NB     0.030369    0.007162       0.469167        0.853125          0.419511
# Ridge  0.044050    0.006267       0.642083        0.999062          0.635629
# XGB    7.968129    0.016810       0.529583        0.989479          0.525260
#
#        train_f1_weighted  test_precision_weighted  train_precision_weighted  \
# model
# NB              0.845305                 0.643821                  0.893990
# Ridge           0.999062                 0.648109                  0.999066
# XGB             0.989475                 0.533682                  0.989589
#
#        test_recall_weighted  train_recall_weighted
# model
# NB                 0.469167               0.853125
# Ridge              0.642083               0.999062
# XGB                0.529583               0.989479

# %%
sd.head()
# Out:
#        fit_time  score_time  test_accuracy  train_accuracy  test_f1_weighted  \
# model
# NB     0.003567    0.001466       0.019510        0.006163          0.017991
# Ridge  0.004334    0.002107       0.024887        0.000436          0.026785
# XGB    2.078235    0.004658       0.019060        0.002481          0.018926
#
#        train_f1_weighted  test_precision_weighted  train_precision_weighted  \
# model
# NB              0.006003                 0.048851                  0.002748
# Ridge           0.000436                 0.029919                  0.000434
# XGB             0.002494                 0.018973                  0.002447
#
#        test_recall_weighted  train_recall_weighted
# model
# NB                 0.019510               0.006163
# Ridge              0.024887               0.000436
# XGB                0.019060               0.002481

# %%
# def get_metrics(true_labels, predicted_labels):
    
#     print('Accuracy:', np.round(
#                         metrics.accuracy_score(true_labels, 
#                                                predicted_labels),
#                         4))
#     print('Precision:', np.round(
#                         metrics.precision_score(true_labels, 
#                                                predicted_labels,
#                                                average='weighted'),
#                         4))
#     print('Recall:', np.round(
#                         metrics.recall_score(true_labels, 
#                                                predicted_labels,
#                                                average='weighted'),
#                         4))
#     print('F1 Score:', np.round(
#                         metrics.f1_score(true_labels, 
#                                                predicted_labels,
#                                                average='weighted'),
#                         4))
                        

# def train_predict_model(classifier, 
#                         train_features, train_labels, 
#                         test_features, test_labels):
#     # build model    
#     classifier.fit(train_features, train_labels)
#     # predict using model
#     predictions = classifier.predict(test_features) 
#     return predictions    


# def display_confusion_matrix(true_labels, predicted_labels, classes=[1,0]):
    
#     total_classes = len(classes)
#     level_labels = [total_classes*[0], list(range(total_classes))]

#     cm = metrics.confusion_matrix(y_true=true_labels, y_pred=predicted_labels, 
#                                   labels=classes)
#     cm_frame = pd.DataFrame(data=cm, 
#                             columns=pd.MultiIndex(levels=[['Predicted:'], classes], 
#                                                   labels=level_labels), 
#                             index=pd.MultiIndex(levels=[['Actual:'], classes], 
#                                                 labels=level_labels)) 
#     print(cm_frame) 
    
def display_classification_report(true_labels, predicted_labels, classes=[1,0]):

    report = metrics.classification_report(y_true=true_labels, 
                                           y_pred=predicted_labels, 
                                           labels=classes) 
    print(report)
    
    
    
# def model_perf(classes, true_labels, predicted_labels):
#     print('Model Performance metrics:')
#     print('-'*30)
#     get_metrics(true_labels=true_labels, predicted_labels=predicted_labels)
#     print('\nModel Classification report:')
#     print('-'*30)
#     display_classification_report(true_labels=true_labels, predicted_labels=predicted_labels, 
#                                   classes=classes)
#     print('\nPrediction Confusion Matrix:')
#     print('-'*30)
#     display_confusion_matrix(true_labels=true_labels, predicted_labels=predicted_labels, 
#                              classes=classes)

# %%
#y_pred_nb = train_predict_model(classifier=NB, train_features=vect.fit_transform(X_train), train_labels=y_train, test_features=vect.transform(X_test), test_labels=y_test)

y_pred_nb = NB.predict(vect.transform(X_test))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb Cell 15 line 3
#       <a href='vscode-notebook-cell:/Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> #y_pred_nb = train_predict_model(classifier=NB, train_features=vect.fit_transform(X_train), train_labels=y_train, test_features=vect.transform(X_test), test_labels=y_test)
# ----> <a href='vscode-notebook-cell:/Users/yaoyao/Desktop/CourseExercise/ENLP/work_flow_usual_model.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> y_pred_nb = NB.predict(vect.transform(X_test))
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/naive_bayes.py:81, in _BaseNB.predict(self, X)
#      67 def predict(self, X):
#      68     """
#      69     Perform classification on an array of test vectors X.
#      70
#    (...)
#      79         Predicted target values for X.
#      80     """
# ---> 81     check_is_fitted(self)
#      82     X = self._check_X(X)
#      83     jll = self._joint_log_likelihood(X)
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/validation.py:1222, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1217     fitted = [
#    1218         v for v in vars(estimator) if v.endswith("_") and not v.startswith("__")
#    1219     ]
#    1221 if not fitted:
# -> 1222     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This MultinomialNB instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
display_classification_report(true_labels=y_test, predicted_labels=y_pred_nb, classes=sorted(y_train.unique()))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.02      0.05        43
#            1       1.00      0.07      0.14        54
#            2       1.00      0.12      0.22        41
#            3       0.86      0.29      0.43        66
#            4       0.44      0.84      0.58        81
#            5       0.49      0.74      0.59        68
#            6       0.92      0.68      0.78        66
#            7       0.79      0.40      0.53        58
#            8       0.24      0.82      0.37        65
#            9       0.94      0.28      0.43        58
#
#     accuracy                           0.47       600
#    macro avg       0.77      0.43      0.41       600
# weighted avg       0.74      0.47      0.44       600

# %%
# import confusion_matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
def plot_confusion_matrix(y_true, y_pred, class_names):
    conf_matrix = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(12, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.tight_layout()
    plt.xticks(range(10), class_names, rotation=90)
    plt.yticks(range(10), class_names, rotation=0)
    plt.legend()
    plt.show()

# %%
plot_confusion_matrix(y_test, y_pred_nb, class_names=sorted(y_train.unique()))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
