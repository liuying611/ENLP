# %%
from mordenNN import *
import pandas as pd
from sklearn.model_selection import train_test_split
from EDA import *
from sklearn.preprocessing import LabelEncoder
from torch.optim import AdamW
import torch.nn.functional as F
import pandas as pd

# %%
def read_data(fpath):
    
    df = pd.read_csv(fpath)
    le = LabelEncoder()
    df['category'] = le.fit_transform(df['category'])
    
    all_words = [w for text in df['text'] for w in text.split()]
    all_words_freq = pd.Series(all_words).value_counts()
        
    train, test = train_test_split(df, test_size=0.2, random_state=42)
    val, test = train_test_split(test, test_size=0.5, random_state=42)
    print(f'Train set length: {len(train)} ; categories: {train["category"].nunique()}')
    print(f'Val set length: {len(val)} ; categories: {val["category"].nunique()}')
    print(f'Test set length: {len(test)} ; categories: {test["category"].nunique()}')
    word2index, index2word = prepare_text_dict(all_words_freq)
    train_data = Data(train, word2index)
    val_data = Data(val, word2index)
    test_data = Data(test, word2index)

    # bert_train_data = Bert_data(train)
    # bert_val_data = Bert_data(val)
    # bert_test_data = Bert_data(test)
    
    # label2encoding = dict(zip(le.classes_, le.transform(le.classes_)))
    # encoding2label = dict(zip(le.transform(le.classes_), le.classes_))
    
    train_loader = DataLoader(train_data, batch_size=32, collate_fn=collate_fn_padded)
    val_loader = DataLoader(val_data, batch_size=32, collate_fn=collate_fn_padded)
    test_loader = DataLoader(test_data, batch_size=32, collate_fn=collate_fn_padded)

    # bert_train_loader = DataLoader(bert_train_data, batch_size=12)
    # bert_val_loader = DataLoader(bert_val_data, batch_size=12)
    # bert_test_loader = DataLoader(bert_test_data, batch_size=12)
    vector_size = 50
    word2vec_embeddings = get_mapping_dict(df, word2index, vector_size= vector_size)
    embedding_matrix = create_embedding_matrix( word2index, word2vec_embeddings, vector_size)
    
    return train_loader, val_loader, test_loader, word2index

# %%
fpaths = [
          #'./data/df_all_category_nobalance.csv', # kernel died
          #'./data/df_10_category_nobalance.csv', # kernel died
          './data/df_10_category_balance.csv',
          './data/df_10_category_balance_60k.csv',
          './data/df_10_category_balance_30k.csv',
          './data/df_10_category_balance_10k_pca.csv',
          './data/df_10_category_balance_3k_pca.csv'
          ]
fpaths = fpaths[::-1]
fnames = ['3k', '10k', '30k', '60k', '100k']
#names = ['3k']
df_lists = [pd.read_csv(fpath) for fpath in fpaths]

# %%
output_size = 10
# common variables for both models
best_embedding_dim = 100
best_hidden_size = 64
# LSTM Model variables
best_n_layers = 2

# variables of CNN
best_n_filters = 32
filter_sizes = [2, 3, 5, 7]
loss_list = {}
f1_list = {}
accuracy_list = {}

for i, df in enumerate(df_lists):
    train_loader, val_loader, test_loader, word2index = read_data(fpaths[i])
    vocab_size = len(word2index)
    print('*************************')
    print(f'start training on dataset: {fpaths[i]}')
    print('Size Of Vocab: ', vocab_size)
    # CNN Model variables
    print(f'CNN Model Starts:')
    model_cnn = CNN_Model(vocab_size, best_embedding_dim, best_hidden_size, best_n_filters, filter_sizes, output_size)
    model_lstm = LSTM_Model(vocab_size, best_embedding_dim, best_hidden_size, best_n_layers, output_size)
    models = [model_cnn, model_lstm]
    loss_function = nn.CrossEntropyLoss().to(device)
    def count_parameters(model):
        # to know how many parametres a 'trained' model has  
        return sum(p.numel() for p in model.parameters() if p.requires_grad)
    
    loss_list[fnames[i]] = {}
    f1_list[fnames[i]] = {}
    accuracy_list[fnames[i]] = {}
    for model in models:
        print('----------------------')
        print('model Name: ', type(model).__name__) # print Model Name
        print(f'{type(model).__name__} has {count_parameters(model):,} trainable parameters') # print Model Total Parameters 
        #model = model.to(device) # convert model to GPU memory for fast training
        optimizer = AdamW(model.parameters(), lr= 0.01, weight_decay=0.01) # assign AdamW as optimizer
        training_model(model, optimizer, loss_function, train_loader, val_loader, epochs=100, using_features=False)
        loss, f1, accuracy, name = pred(model, test_loader, loss_function, using_features=False)
        loss_list[fnames[i]][name] = loss
        f1_list[fnames[i]][name] = f1
        accuracy_list[fnames[i]][name] = accuracy
# Out:
# Train set length: 2400 ; categories: 10
# Val set length: 300 ; categories: 10
# Test set length: 300 ; categories: 10
#
# word2vec embeddings...
# word2vec embeddings found for our vocabs: 12792 | missing: 0 ; 0.0%
# *************************
# start training on dataset: ./data/df_10_category_balance_3k_pca.csv
# Size Of Vocab:  12792
# CNN Model Starts:
# ----------------------
# model Name:  CNN_Model
# CNN_Model has 1,335,018 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.7354 | acc: 17.5 | f1-score: 10.9) & Eval(loss: 2.2319 | acc: 28.4 | f1-score: 19.0)
#
# BEST Epoch(2 | Train(loss: 2.2873 | acc: 32.0 | f1-score: 23.1) & Eval(loss: 1.8782 | acc: 32.0 | f1-score: 24.0)
#
# BEST Epoch(3 | Train(loss: 1.8122 | acc: 47.4 | f1-score: 37.8) & Eval(loss: 2.0148 | acc: 38.0 | f1-score: 32.1)
#
# BEST Epoch(4 | Train(loss: 1.3646 | acc: 63.0 | f1-score: 54.1) & Eval(loss: 2.2551 | acc: 46.6 | f1-score: 37.7)
#
# Epoch(5 | Train(loss: 0.9567 | acc: 75.6 | f1-score: 68.9) & Eval(loss: 3.0873 | acc: 45.0 | f1-score: 39.9)
#
# Epoch(6 | Train(loss: 0.7004 | acc: 83.1 | f1-score: 77.5) & Eval(loss: 4.1036 | acc: 42.4 | f1-score: 36.9)
#
# BEST Epoch(7 | Train(loss: 0.649 | acc: 86.0 | f1-score: 80.3) & Eval(loss: 4.3202 | acc: 47.3 | f1-score: 41.4)
#
# BEST Epoch(8 | Train(loss: 0.5665 | acc: 88.8 | f1-score: 84.1) & Eval(loss: 6.0442 | acc: 47.5 | f1-score: 39.8)
#
# Epoch(9 | Train(loss: 0.5543 | acc: 89.9 | f1-score: 85.9) & Eval(loss: 7.2411 | acc: 41.8 | f1-score: 33.5)
#
# BEST Epoch(10 | Train(loss: 0.5224 | acc: 91.5 | f1-score: 88.2) & Eval(loss: 6.8444 | acc: 50.3 | f1-score: 44.1)
#
# Epoch(11 | Train(loss: 0.3883 | acc: 93.3 | f1-score: 90.6) & Eval(loss: 9.1379 | acc: 48.6 | f1-score: 41.4)
#
# BEST Epoch(12 | Train(loss: 0.403 | acc: 94.2 | f1-score: 91.7) & Eval(loss: 8.6741 | acc: 50.5 | f1-score: 44.3)
#
# Epoch(13 | Train(loss: 0.3611 | acc: 95.0 | f1-score: 92.5) & Eval(loss: 9.7811 | acc: 45.8 | f1-score: 39.2)
#
# Epoch(14 | Train(loss: 0.3507 | acc: 95.0 | f1-score: 93.0) & Eval(loss: 10.8507 | acc: 45.8 | f1-score: 39.0)
#
# Epoch(15 | Train(loss: 0.372 | acc: 95.2 | f1-score: 92.5) & Eval(loss: 10.6979 | acc: 49.2 | f1-score: 42.0)
#
# Epoch(16 | Train(loss: 0.3027 | acc: 95.6 | f1-score: 94.3) & Eval(loss: 11.9519 | acc: 48.2 | f1-score: 40.8)
#
# BEST Epoch(17 | Train(loss: 0.4088 | acc: 95.5 | f1-score: 93.4) & Eval(loss: 12.4541 | acc: 51.8 | f1-score: 42.3)
#
# BEST Epoch(18 | Train(loss: 0.3459 | acc: 96.6 | f1-score: 94.8) & Eval(loss: 12.9217 | acc: 52.9 | f1-score: 45.1)
#
# BEST Epoch(19 | Train(loss: 0.2684 | acc: 97.0 | f1-score: 96.0) & Eval(loss: 12.4854 | acc: 54.2 | f1-score: 47.7)
#
# Epoch(20 | Train(loss: 0.2402 | acc: 96.9 | f1-score: 95.0) & Eval(loss: 12.8515 | acc: 52.9 | f1-score: 44.7)
#
# Epoch(21 | Train(loss: 0.2083 | acc: 97.4 | f1-score: 96.1) & Eval(loss: 14.2422 | acc: 54.2 | f1-score: 46.3)
#
# Epoch(22 | Train(loss: 0.2567 | acc: 97.3 | f1-score: 96.2) & Eval(loss: 14.2294 | acc: 53.0 | f1-score: 45.9)
#
# BEST Epoch(23 | Train(loss: 0.275 | acc: 97.3 | f1-score: 95.7) & Eval(loss: 13.6178 | acc: 57.0 | f1-score: 50.2)
#
# Epoch(24 | Train(loss: 0.3803 | acc: 97.1 | f1-score: 95.6) & Eval(loss: 14.6241 | acc: 53.9 | f1-score: 48.1)
#
# Epoch(25 | Train(loss: 0.1793 | acc: 97.7 | f1-score: 96.6) & Eval(loss: 14.3234 | acc: 55.5 | f1-score: 51.2)
#
# Epoch(26 | Train(loss: 0.2682 | acc: 97.7 | f1-score: 96.3) & Eval(loss: 15.633 | acc: 57.0 | f1-score: 51.8)
#
# Epoch(27 | Train(loss: 0.243 | acc: 97.7 | f1-score: 96.2) & Eval(loss: 15.4141 | acc: 56.1 | f1-score: 51.4)
#
# Epoch(28 | Train(loss: 0.2459 | acc: 97.5 | f1-score: 96.4) & Eval(loss: 16.1978 | acc: 57.0 | f1-score: 51.6)
#
# EARLY STOPPING!
# BEST EPOCH(23 | Train(loss:0.275 | acc:97.3 | f1-score:95.7) & Eval(loss: 13.6178 | acc: 57.0 | f1-score: 50.2)
#
# ----------------------
# model Name:  LSTM_Model
# LSTM_Model has 1,359,786 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.2371 | acc: 16.5 | f1-score: 6.6) & Eval(loss: 2.3025 | acc: 12.6 | f1-score: 3.5)
#
# BEST Epoch(2 | Train(loss: 2.1993 | acc: 19.5 | f1-score: 8.4) & Eval(loss: 2.1704 | acc: 17.3 | f1-score: 7.9)
#
# BEST Epoch(3 | Train(loss: 2.0147 | acc: 25.5 | f1-score: 14.3) & Eval(loss: 2.1762 | acc: 18.5 | f1-score: 8.3)
#
# Epoch(4 | Train(loss: 1.8278 | acc: 27.7 | f1-score: 16.2) & Eval(loss: 2.2901 | acc: 17.7 | f1-score: 8.9)
#
# BEST Epoch(5 | Train(loss: 1.644 | acc: 33.8 | f1-score: 22.1) & Eval(loss: 2.2601 | acc: 22.9 | f1-score: 13.6)
#
# Epoch(6 | Train(loss: 1.4425 | acc: 39.2 | f1-score: 28.0) & Eval(loss: 2.4035 | acc: 22.7 | f1-score: 14.1)
#
# Epoch(7 | Train(loss: 1.2716 | acc: 44.8 | f1-score: 33.1) & Eval(loss: 2.5785 | acc: 22.6 | f1-score: 15.8)
#
# Epoch(8 | Train(loss: 1.1823 | acc: 49.0 | f1-score: 38.8) & Eval(loss: 2.8603 | acc: 22.7 | f1-score: 15.6)
#
# BEST Epoch(9 | Train(loss: 1.1063 | acc: 51.5 | f1-score: 43.0) & Eval(loss: 2.7109 | acc: 25.2 | f1-score: 18.4)
#
# BEST Epoch(10 | Train(loss: 1.0085 | acc: 55.7 | f1-score: 47.5) & Eval(loss: 2.548 | acc: 26.1 | f1-score: 18.2)
#
# Epoch(11 | Train(loss: 0.8485 | acc: 63.8 | f1-score: 56.5) & Eval(loss: 2.8315 | acc: 25.4 | f1-score: 20.1)
#
# Epoch(12 | Train(loss: 0.8082 | acc: 66.8 | f1-score: 61.1) & Eval(loss: 2.7787 | acc: 24.5 | f1-score: 22.0)
#
# BEST Epoch(13 | Train(loss: 0.7133 | acc: 70.7 | f1-score: 66.8) & Eval(loss: 3.2799 | acc: 27.6 | f1-score: 24.1)
#
# BEST Epoch(14 | Train(loss: 0.5877 | acc: 75.7 | f1-score: 71.3) & Eval(loss: 3.2275 | acc: 30.1 | f1-score: 25.4)
#
# Epoch(15 | Train(loss: 0.5848 | acc: 76.9 | f1-score: 73.7) & Eval(loss: 3.622 | acc: 28.6 | f1-score: 25.4)
#
# Epoch(16 | Train(loss: 0.5188 | acc: 79.7 | f1-score: 76.7) & Eval(loss: 3.8779 | acc: 27.8 | f1-score: 24.6)
#
# BEST Epoch(17 | Train(loss: 0.4629 | acc: 84.1 | f1-score: 81.3) & Eval(loss: 3.8485 | acc: 33.2 | f1-score: 28.8)
#
# BEST Epoch(18 | Train(loss: 0.4142 | acc: 85.5 | f1-score: 83.6) & Eval(loss: 4.0085 | acc: 35.0 | f1-score: 31.0)
#
# BEST Epoch(19 | Train(loss: 0.3353 | acc: 89.2 | f1-score: 87.2) & Eval(loss: 3.9017 | acc: 35.9 | f1-score: 32.6)
#
# BEST Epoch(20 | Train(loss: 0.356 | acc: 88.9 | f1-score: 86.9) & Eval(loss: 4.2133 | acc: 36.0 | f1-score: 30.2)
#
# Epoch(21 | Train(loss: 0.3258 | acc: 91.7 | f1-score: 89.7) & Eval(loss: 3.9339 | acc: 31.2 | f1-score: 26.3)
#
# BEST Epoch(22 | Train(loss: 0.2455 | acc: 92.9 | f1-score: 91.1) & Eval(loss: 3.9703 | acc: 40.3 | f1-score: 35.1)
#
# BEST Epoch(23 | Train(loss: 0.2169 | acc: 94.3 | f1-score: 92.8) & Eval(loss: 4.2583 | acc: 41.5 | f1-score: 33.7)
#
# Epoch(24 | Train(loss: 0.2175 | acc: 94.3 | f1-score: 92.8) & Eval(loss: 4.1085 | acc: 39.2 | f1-score: 33.0)
#
# Epoch(25 | Train(loss: 0.231 | acc: 94.5 | f1-score: 91.8) & Eval(loss: 4.1255 | acc: 41.4 | f1-score: 35.5)
#
# Epoch(26 | Train(loss: 0.144 | acc: 96.1 | f1-score: 94.7) & Eval(loss: 4.5248 | acc: 40.0 | f1-score: 36.8)
#
# BEST Epoch(27 | Train(loss: 0.1669 | acc: 95.6 | f1-score: 93.4) & Eval(loss: 4.5427 | acc: 44.4 | f1-score: 38.0)
#
# Epoch(28 | Train(loss: 0.1789 | acc: 95.4 | f1-score: 93.0) & Eval(loss: 4.7524 | acc: 42.1 | f1-score: 35.5)
#
# Epoch(29 | Train(loss: 0.1721 | acc: 95.8 | f1-score: 93.1) & Eval(loss: 4.2906 | acc: 44.0 | f1-score: 38.6)
#
# Epoch(30 | Train(loss: 0.1139 | acc: 96.6 | f1-score: 95.9) & Eval(loss: 4.8422 | acc: 42.5 | f1-score: 38.2)
#
# Epoch(31 | Train(loss: 0.1573 | acc: 96.8 | f1-score: 95.9) & Eval(loss: 4.6284 | acc: 39.2 | f1-score: 35.4)
#
# Epoch(32 | Train(loss: 0.1262 | acc: 96.9 | f1-score: 95.8) & Eval(loss: 5.1982 | acc: 38.6 | f1-score: 32.9)
#
# EARLY STOPPING!
# BEST EPOCH(27 | Train(loss:0.1669 | acc:95.6 | f1-score:93.4) & Eval(loss: 4.5427 | acc: 44.4 | f1-score: 38.0)
#
# Train set length: 8000 ; categories: 10
# Val set length: 1000 ; categories: 10
# Test set length: 1000 ; categories: 10
#
# word2vec embeddings...
# word2vec embeddings found for our vocabs: 24496 | missing: 0 ; 0.0%
# *************************
# start training on dataset: ./data/df_10_category_balance_10k_pca.csv
# Size Of Vocab:  24496
# CNN Model Starts:
# ----------------------
# model Name:  CNN_Model
# CNN_Model has 2,505,418 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.5407 | acc: 23.8 | f1-score: 16.5) & Eval(loss: 1.9717 | acc: 34.1 | f1-score: 23.9)
#
# BEST Epoch(2 | Train(loss: 1.9711 | acc: 42.5 | f1-score: 33.5) & Eval(loss: 1.6604 | acc: 52.0 | f1-score: 41.8)
#
# BEST Epoch(3 | Train(loss: 1.4275 | acc: 60.1 | f1-score: 52.1) & Eval(loss: 1.9445 | acc: 53.7 | f1-score: 46.2)
#
# Epoch(4 | Train(loss: 1.1141 | acc: 71.9 | f1-score: 65.1) & Eval(loss: 2.9207 | acc: 50.6 | f1-score: 42.4)
#
# BEST Epoch(5 | Train(loss: 0.9038 | acc: 79.3 | f1-score: 73.5) & Eval(loss: 3.814 | acc: 55.8 | f1-score: 45.4)
#
# Epoch(6 | Train(loss: 0.8464 | acc: 82.8 | f1-score: 77.3) & Eval(loss: 4.4226 | acc: 55.1 | f1-score: 46.2)
#
# Epoch(7 | Train(loss: 0.7683 | acc: 84.9 | f1-score: 80.6) & Eval(loss: 5.2798 | acc: 55.3 | f1-score: 44.6)
#
# Epoch(8 | Train(loss: 0.6865 | acc: 87.0 | f1-score: 82.9) & Eval(loss: 6.1253 | acc: 55.4 | f1-score: 45.5)
#
# BEST Epoch(9 | Train(loss: 0.624 | acc: 89.5 | f1-score: 86.2) & Eval(loss: 6.5974 | acc: 58.0 | f1-score: 47.1)
#
# Epoch(10 | Train(loss: 0.6327 | acc: 90.3 | f1-score: 87.0) & Eval(loss: 7.1281 | acc: 56.5 | f1-score: 46.7)
#
# Epoch(11 | Train(loss: 0.5668 | acc: 91.8 | f1-score: 89.3) & Eval(loss: 8.4746 | acc: 55.9 | f1-score: 46.7)
#
# Epoch(12 | Train(loss: 0.6416 | acc: 91.6 | f1-score: 89.0) & Eval(loss: 9.4079 | acc: 56.2 | f1-score: 45.7)
#
# Epoch(13 | Train(loss: 0.5975 | acc: 92.0 | f1-score: 89.1) & Eval(loss: 9.3281 | acc: 57.1 | f1-score: 48.2)
#
# Epoch(14 | Train(loss: 0.4793 | acc: 93.6 | f1-score: 91.2) & Eval(loss: 10.5585 | acc: 56.4 | f1-score: 47.8)
#
# EARLY STOPPING!
# BEST EPOCH(9 | Train(loss:0.624 | acc:89.5 | f1-score:86.2) & Eval(loss: 6.5974 | acc: 58.0 | f1-score: 47.1)
#
# ----------------------
# model Name:  LSTM_Model
# LSTM_Model has 2,530,186 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.0946 | acc: 23.7 | f1-score: 12.1) & Eval(loss: 2.0807 | acc: 21.0 | f1-score: 11.3)
#
# BEST Epoch(2 | Train(loss: 1.7697 | acc: 33.5 | f1-score: 22.2) & Eval(loss: 1.84 | acc: 33.3 | f1-score: 21.8)
#
# BEST Epoch(3 | Train(loss: 1.483 | acc: 42.6 | f1-score: 31.0) & Eval(loss: 1.9332 | acc: 34.9 | f1-score: 25.0)
#
# BEST Epoch(4 | Train(loss: 1.2632 | acc: 51.6 | f1-score: 41.8) & Eval(loss: 2.0116 | acc: 39.6 | f1-score: 29.6)
#
# BEST Epoch(5 | Train(loss: 1.0708 | acc: 59.8 | f1-score: 52.6) & Eval(loss: 1.8473 | acc: 42.4 | f1-score: 34.9)
#
# BEST Epoch(6 | Train(loss: 0.8829 | acc: 68.9 | f1-score: 62.6) & Eval(loss: 2.1135 | acc: 46.9 | f1-score: 38.2)
#
# Epoch(7 | Train(loss: 0.7744 | acc: 74.5 | f1-score: 68.5) & Eval(loss: 2.1176 | acc: 46.5 | f1-score: 38.9)
#
# BEST Epoch(8 | Train(loss: 0.6558 | acc: 79.5 | f1-score: 73.5) & Eval(loss: 2.1093 | acc: 47.6 | f1-score: 39.8)
#
# BEST Epoch(9 | Train(loss: 0.5345 | acc: 83.6 | f1-score: 78.8) & Eval(loss: 2.2223 | acc: 50.1 | f1-score: 42.5)
#
# BEST Epoch(10 | Train(loss: 0.4478 | acc: 87.4 | f1-score: 83.5) & Eval(loss: 2.2009 | acc: 51.8 | f1-score: 44.2)
#
# Epoch(11 | Train(loss: 0.3941 | acc: 89.2 | f1-score: 85.7) & Eval(loss: 2.464 | acc: 50.2 | f1-score: 43.0)
#
# BEST Epoch(12 | Train(loss: 0.3377 | acc: 91.0 | f1-score: 88.0) & Eval(loss: 2.7341 | acc: 52.2 | f1-score: 44.1)
#
# BEST Epoch(13 | Train(loss: 0.3265 | acc: 91.3 | f1-score: 88.1) & Eval(loss: 2.628 | acc: 54.4 | f1-score: 46.6)
#
# Epoch(14 | Train(loss: 0.2778 | acc: 93.1 | f1-score: 90.4) & Eval(loss: 2.9018 | acc: 54.0 | f1-score: 45.5)
#
# BEST Epoch(15 | Train(loss: 0.2393 | acc: 94.0 | f1-score: 91.7) & Eval(loss: 3.0387 | acc: 55.6 | f1-score: 46.8)
#
# Epoch(16 | Train(loss: 0.2377 | acc: 93.8 | f1-score: 91.3) & Eval(loss: 2.89 | acc: 52.6 | f1-score: 45.6)
#
# Epoch(17 | Train(loss: 0.204 | acc: 95.0 | f1-score: 93.3) & Eval(loss: 3.0678 | acc: 55.4 | f1-score: 48.0)
#
# Epoch(18 | Train(loss: 0.1912 | acc: 95.6 | f1-score: 93.9) & Eval(loss: 3.0451 | acc: 53.5 | f1-score: 46.3)
#
# Epoch(19 | Train(loss: 0.1851 | acc: 95.4 | f1-score: 93.7) & Eval(loss: 3.322 | acc: 53.4 | f1-score: 46.4)
#
# Epoch(20 | Train(loss: 0.1764 | acc: 95.6 | f1-score: 93.8) & Eval(loss: 3.2762 | acc: 55.3 | f1-score: 47.0)
#
# EARLY STOPPING!
# BEST EPOCH(15 | Train(loss:0.2393 | acc:94.0 | f1-score:91.7) & Eval(loss: 3.0387 | acc: 55.6 | f1-score: 46.8)
#
# Train set length: 24000 ; categories: 10
# Val set length: 3000 ; categories: 10
# Test set length: 3000 ; categories: 10
#
# word2vec embeddings...
# word2vec embeddings found for our vocabs: 42189 | missing: 0 ; 0.0%
# *************************
# start training on dataset: ./data/df_10_category_balance_30k.csv
# Size Of Vocab:  42189
# CNN Model Starts:
# ----------------------
# model Name:  CNN_Model
# CNN_Model has 4,274,718 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1367 | acc: 36.8 | f1-score: 27.9) & Eval(loss: 1.4829 | acc: 50.6 | f1-score: 42.6)
#
# BEST Epoch(2 | Train(loss: 1.566 | acc: 56.6 | f1-score: 47.9) & Eval(loss: 1.5467 | acc: 55.8 | f1-score: 48.6)
#
# BEST Epoch(3 | Train(loss: 1.2963 | acc: 65.0 | f1-score: 57.4) & Eval(loss: 1.6692 | acc: 56.0 | f1-score: 49.0)
#
# BEST Epoch(4 | Train(loss: 1.1523 | acc: 70.1 | f1-score: 63.2) & Eval(loss: 1.7898 | acc: 57.4 | f1-score: 50.5)
#
# Epoch(5 | Train(loss: 1.0586 | acc: 73.5 | f1-score: 66.9) & Eval(loss: 1.9874 | acc: 56.3 | f1-score: 49.2)
#
# BEST Epoch(6 | Train(loss: 0.9619 | acc: 76.3 | f1-score: 70.2) & Eval(loss: 2.2169 | acc: 59.4 | f1-score: 52.2)
#
# Epoch(7 | Train(loss: 0.895 | acc: 79.1 | f1-score: 73.4) & Eval(loss: 2.3738 | acc: 59.2 | f1-score: 52.1)
#
# BEST Epoch(8 | Train(loss: 0.8637 | acc: 80.4 | f1-score: 74.9) & Eval(loss: 2.4945 | acc: 60.0 | f1-score: 53.8)
#
# Epoch(9 | Train(loss: 0.8057 | acc: 81.4 | f1-score: 76.2) & Eval(loss: 2.717 | acc: 59.7 | f1-score: 52.6)
#
# BEST Epoch(10 | Train(loss: 0.7967 | acc: 82.4 | f1-score: 77.2) & Eval(loss: 2.9418 | acc: 61.3 | f1-score: 55.0)
#
# BEST Epoch(11 | Train(loss: 0.7509 | acc: 83.8 | f1-score: 78.8) & Eval(loss: 3.1685 | acc: 61.7 | f1-score: 55.0)
#
# BEST Epoch(12 | Train(loss: 0.7335 | acc: 84.3 | f1-score: 79.8) & Eval(loss: 3.1227 | acc: 62.2 | f1-score: 54.8)
#
# BEST Epoch(13 | Train(loss: 0.7223 | acc: 85.0 | f1-score: 80.8) & Eval(loss: 3.3659 | acc: 62.4 | f1-score: 56.6)
#
# Epoch(14 | Train(loss: 0.7302 | acc: 85.4 | f1-score: 80.8) & Eval(loss: 3.3322 | acc: 59.8 | f1-score: 52.9)
#
# Epoch(15 | Train(loss: 0.7144 | acc: 85.5 | f1-score: 81.5) & Eval(loss: 3.4705 | acc: 61.2 | f1-score: 54.9)
#
# Epoch(16 | Train(loss: 0.6838 | acc: 86.4 | f1-score: 82.5) & Eval(loss: 3.7826 | acc: 59.6 | f1-score: 53.4)
#
# Epoch(17 | Train(loss: 0.684 | acc: 86.5 | f1-score: 82.3) & Eval(loss: 3.5857 | acc: 61.8 | f1-score: 55.8)
#
# Epoch(18 | Train(loss: 0.6854 | acc: 87.0 | f1-score: 82.9) & Eval(loss: 3.7979 | acc: 61.5 | f1-score: 54.8)
#
# EARLY STOPPING!
# BEST EPOCH(13 | Train(loss:0.7223 | acc:85.0 | f1-score:80.8) & Eval(loss: 3.3659 | acc: 62.4 | f1-score: 56.6)
#
# ----------------------
# model Name:  LSTM_Model
# LSTM_Model has 4,299,486 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 1.8073 | acc: 35.5 | f1-score: 25.2) & Eval(loss: 1.5865 | acc: 42.4 | f1-score: 34.5)
#
# BEST Epoch(2 | Train(loss: 1.3198 | acc: 55.1 | f1-score: 45.4) & Eval(loss: 1.3179 | acc: 54.3 | f1-score: 47.4)
#
# BEST Epoch(3 | Train(loss: 1.0374 | acc: 67.1 | f1-score: 58.7) & Eval(loss: 1.2167 | acc: 63.3 | f1-score: 57.0)
#
# BEST Epoch(4 | Train(loss: 0.8609 | acc: 74.0 | f1-score: 67.0) & Eval(loss: 1.1951 | acc: 64.1 | f1-score: 57.3)
#
# BEST Epoch(5 | Train(loss: 0.7371 | acc: 78.7 | f1-score: 72.2) & Eval(loss: 1.2089 | acc: 65.8 | f1-score: 58.6)
#
# Epoch(6 | Train(loss: 0.6287 | acc: 81.9 | f1-score: 76.3) & Eval(loss: 1.2468 | acc: 65.2 | f1-score: 58.8)
#
# Epoch(7 | Train(loss: 0.5568 | acc: 84.6 | f1-score: 79.3) & Eval(loss: 1.2484 | acc: 64.8 | f1-score: 58.8)
#
# BEST Epoch(8 | Train(loss: 0.505 | acc: 86.4 | f1-score: 81.7) & Eval(loss: 1.2501 | acc: 66.8 | f1-score: 60.1)
#
# Epoch(9 | Train(loss: 0.4538 | acc: 88.0 | f1-score: 83.7) & Eval(loss: 1.2814 | acc: 66.1 | f1-score: 60.0)
#
# Epoch(10 | Train(loss: 0.4284 | acc: 89.0 | f1-score: 85.1) & Eval(loss: 1.3794 | acc: 66.4 | f1-score: 60.0)
#
# BEST Epoch(11 | Train(loss: 0.3745 | acc: 90.1 | f1-score: 86.6) & Eval(loss: 1.4256 | acc: 67.0 | f1-score: 60.5)
#
# Epoch(12 | Train(loss: 0.3423 | acc: 91.0 | f1-score: 87.6) & Eval(loss: 1.5214 | acc: 66.8 | f1-score: 60.0)
#
# Epoch(13 | Train(loss: 0.3177 | acc: 91.8 | f1-score: 88.7) & Eval(loss: 1.6943 | acc: 65.4 | f1-score: 58.4)
#
# Epoch(14 | Train(loss: 0.3069 | acc: 92.2 | f1-score: 89.3) & Eval(loss: 1.6366 | acc: 66.3 | f1-score: 58.9)
#
# Epoch(15 | Train(loss: 0.2926 | acc: 92.4 | f1-score: 89.3) & Eval(loss: 1.6235 | acc: 65.5 | f1-score: 58.3)
#
# Epoch(16 | Train(loss: 0.2922 | acc: 92.5 | f1-score: 89.8) & Eval(loss: 1.4746 | acc: 66.2 | f1-score: 59.5)
#
# EARLY STOPPING!
# BEST EPOCH(11 | Train(loss:0.3745 | acc:90.1 | f1-score:86.6) & Eval(loss: 1.4256 | acc: 67.0 | f1-score: 60.5)
#
# Train set length: 48000 ; categories: 10
# Val set length: 6000 ; categories: 10
# Test set length: 6000 ; categories: 10
#
# word2vec embeddings...
# word2vec embeddings found for our vocabs: 59146 | missing: 0 ; 0.0%
# *************************
# start training on dataset: ./data/df_10_category_balance_60k.csv
# Size Of Vocab:  59146
# CNN Model Starts:
# ----------------------
# model Name:  CNN_Model
# CNN_Model has 5,970,418 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 1.9019 | acc: 45.5 | f1-score: 37.1) & Eval(loss: 1.3862 | acc: 56.6 | f1-score: 50.3)
#
# BEST Epoch(2 | Train(loss: 1.4309 | acc: 60.4 | f1-score: 52.3) & Eval(loss: 1.435 | acc: 57.7 | f1-score: 50.8)
#
# Epoch(3 | Train(loss: 1.2951 | acc: 65.4 | f1-score: 57.6) & Eval(loss: 1.4913 | acc: 57.6 | f1-score: 52.6)
#
# Epoch(4 | Train(loss: 1.1761 | acc: 69.0 | f1-score: 61.8) & Eval(loss: 1.5705 | acc: 57.7 | f1-score: 52.9)
#
# BEST Epoch(5 | Train(loss: 1.1063 | acc: 71.5 | f1-score: 64.6) & Eval(loss: 1.662 | acc: 59.9 | f1-score: 54.3)
#
# BEST Epoch(6 | Train(loss: 1.046 | acc: 73.5 | f1-score: 67.0) & Eval(loss: 1.7913 | acc: 60.3 | f1-score: 54.5)
#
# Epoch(7 | Train(loss: 1.0157 | acc: 74.8 | f1-score: 68.7) & Eval(loss: 1.8024 | acc: 59.4 | f1-score: 53.8)
#
# Epoch(8 | Train(loss: 0.9712 | acc: 75.8 | f1-score: 69.7) & Eval(loss: 1.9109 | acc: 59.1 | f1-score: 53.4)
#
# Epoch(9 | Train(loss: 0.9359 | acc: 77.1 | f1-score: 71.3) & Eval(loss: 2.0205 | acc: 59.1 | f1-score: 53.0)
#
# BEST Epoch(10 | Train(loss: 0.9127 | acc: 77.7 | f1-score: 72.0) & Eval(loss: 2.0118 | acc: 60.7 | f1-score: 54.5)
#
# Epoch(11 | Train(loss: 0.8964 | acc: 78.2 | f1-score: 72.5) & Eval(loss: 2.138 | acc: 60.6 | f1-score: 53.9)
#
# Epoch(12 | Train(loss: 0.8799 | acc: 78.8 | f1-score: 72.9) & Eval(loss: 2.1389 | acc: 59.4 | f1-score: 52.8)
#
# Epoch(13 | Train(loss: 0.8631 | acc: 79.0 | f1-score: 73.5) & Eval(loss: 2.289 | acc: 57.2 | f1-score: 50.1)
#
# Epoch(14 | Train(loss: 0.8548 | acc: 79.4 | f1-score: 74.0) & Eval(loss: 2.1735 | acc: 60.7 | f1-score: 54.7)
#
# Epoch(15 | Train(loss: 0.8489 | acc: 79.8 | f1-score: 74.5) & Eval(loss: 2.2207 | acc: 58.1 | f1-score: 52.4)
#
# EARLY STOPPING!
# BEST EPOCH(10 | Train(loss:0.9127 | acc:77.7 | f1-score:72.0) & Eval(loss: 2.0118 | acc: 60.7 | f1-score: 54.5)
#
# ----------------------
# model Name:  LSTM_Model
# LSTM_Model has 5,995,186 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 1.6117 | acc: 45.6 | f1-score: 33.9) & Eval(loss: 1.3445 | acc: 55.7 | f1-score: 48.9)
#
# BEST Epoch(2 | Train(loss: 1.1503 | acc: 64.3 | f1-score: 55.7) & Eval(loss: 1.1268 | acc: 63.6 | f1-score: 57.1)
#
# BEST Epoch(3 | Train(loss: 0.9209 | acc: 72.6 | f1-score: 65.4) & Eval(loss: 1.029 | acc: 68.5 | f1-score: 62.5)
#
# BEST Epoch(4 | Train(loss: 0.7809 | acc: 77.5 | f1-score: 71.2) & Eval(loss: 1.0221 | acc: 69.6 | f1-score: 63.6)
#
# BEST Epoch(5 | Train(loss: 0.6829 | acc: 80.6 | f1-score: 74.8) & Eval(loss: 1.0833 | acc: 69.9 | f1-score: 63.6)
#
# BEST Epoch(6 | Train(loss: 0.6121 | acc: 82.8 | f1-score: 77.7) & Eval(loss: 1.1131 | acc: 70.6 | f1-score: 64.7)
#
# Epoch(7 | Train(loss: 0.5591 | acc: 84.3 | f1-score: 79.6) & Eval(loss: 1.1231 | acc: 70.5 | f1-score: 64.6)
#
# Epoch(8 | Train(loss: 0.5208 | acc: 85.8 | f1-score: 81.3) & Eval(loss: 1.2102 | acc: 69.8 | f1-score: 63.4)
#
# Epoch(9 | Train(loss: 0.4819 | acc: 86.8 | f1-score: 82.5) & Eval(loss: 1.1575 | acc: 70.0 | f1-score: 63.6)
#
# Epoch(10 | Train(loss: 0.4518 | acc: 87.7 | f1-score: 83.8) & Eval(loss: 1.2751 | acc: 69.4 | f1-score: 63.7)
#
# Epoch(11 | Train(loss: 0.4329 | acc: 88.4 | f1-score: 84.7) & Eval(loss: 1.2522 | acc: 69.8 | f1-score: 63.3)
#
# EARLY STOPPING!
# BEST EPOCH(6 | Train(loss:0.6121 | acc:82.8 | f1-score:77.7) & Eval(loss: 1.1131 | acc: 70.6 | f1-score: 64.7)
#
# Train set length: 76665 ; categories: 10
# Val set length: 9583 ; categories: 10
# Test set length: 9584 ; categories: 10
#
# word2vec embeddings...
# word2vec embeddings found for our vocabs: 74570 | missing: 0 ; 0.0%
# *************************
# start training on dataset: ./data/df_10_category_balance.csv
# Size Of Vocab:  74570
# CNN Model Starts:
# ----------------------
# model Name:  CNN_Model
# CNN_Model has 7,512,818 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 1.768 | acc: 49.5 | f1-score: 40.7) & Eval(loss: 1.4195 | acc: 56.5 | f1-score: 48.9)
#
# BEST Epoch(2 | Train(loss: 1.3898 | acc: 61.2 | f1-score: 52.9) & Eval(loss: 1.2605 | acc: 61.2 | f1-score: 54.3)
#
# BEST Epoch(3 | Train(loss: 1.278 | acc: 65.3 | f1-score: 57.4) & Eval(loss: 1.2736 | acc: 63.0 | f1-score: 55.9)
#
# Epoch(4 | Train(loss: 1.202 | acc: 67.7 | f1-score: 60.3) & Eval(loss: 1.3645 | acc: 61.4 | f1-score: 54.4)
#
# Epoch(5 | Train(loss: 1.1391 | acc: 69.6 | f1-score: 62.4) & Eval(loss: 1.4199 | acc: 60.3 | f1-score: 53.8)
#
# Epoch(6 | Train(loss: 1.1118 | acc: 70.9 | f1-score: 64.0) & Eval(loss: 1.3797 | acc: 62.5 | f1-score: 55.4)
#
# Epoch(7 | Train(loss: 1.0942 | acc: 71.4 | f1-score: 64.5) & Eval(loss: 1.4344 | acc: 61.4 | f1-score: 54.7)
#
# Epoch(8 | Train(loss: 1.0655 | acc: 72.4 | f1-score: 65.7) & Eval(loss: 1.4893 | acc: 61.7 | f1-score: 54.8)
#
# EARLY STOPPING!
# BEST EPOCH(3 | Train(loss:1.278 | acc:65.3 | f1-score:57.4) & Eval(loss: 1.2736 | acc: 63.0 | f1-score: 55.9)
#
# ----------------------
# model Name:  LSTM_Model
# LSTM_Model has 7,537,586 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 1.4369 | acc: 53.3 | f1-score: 42.9) & Eval(loss: 1.1989 | acc: 63.4 | f1-score: 56.0)
#
# BEST Epoch(2 | Train(loss: 1.0057 | acc: 69.8 | f1-score: 62.2) & Eval(loss: 0.9333 | acc: 70.5 | f1-score: 63.1)
#
# BEST Epoch(3 | Train(loss: 0.8331 | acc: 75.9 | f1-score: 69.1) & Eval(loss: 0.8722 | acc: 73.3 | f1-score: 66.8)
#
# BEST Epoch(4 | Train(loss: 0.7334 | acc: 78.9 | f1-score: 72.7) & Eval(loss: 0.8676 | acc: 74.1 | f1-score: 67.6)
#
# Epoch(5 | Train(loss: 0.6596 | acc: 81.2 | f1-score: 75.4) & Eval(loss: 0.898 | acc: 74.1 | f1-score: 67.3)
#
# Epoch(6 | Train(loss: 0.6168 | acc: 82.6 | f1-score: 77.3) & Eval(loss: 0.9338 | acc: 73.7 | f1-score: 66.6)
#
# Epoch(7 | Train(loss: 0.5803 | acc: 84.0 | f1-score: 79.1) & Eval(loss: 0.9555 | acc: 74.0 | f1-score: 66.7)
#
# Epoch(8 | Train(loss: 0.5555 | acc: 84.7 | f1-score: 79.9) & Eval(loss: 1.0414 | acc: 73.1 | f1-score: 66.4)
#
# Epoch(9 | Train(loss: 0.5363 | acc: 85.4 | f1-score: 80.8) & Eval(loss: 1.001 | acc: 73.2 | f1-score: 66.3)
#
# EARLY STOPPING!
# BEST EPOCH(4 | Train(loss:0.7334 | acc:78.9 | f1-score:72.7) & Eval(loss: 0.8676 | acc: 74.1 | f1-score: 67.6)

# %%
loss_list
# Out:
# {'3k': {'CNN_Model': 14.988, 'LSTM_Model': 4.9677},
#  '10k': {'CNN_Model': 9.5692, 'LSTM_Model': 3.08},
#  '30k': {'CNN_Model': 3.5955, 'LSTM_Model': 1.504},
#  '60k': {'CNN_Model': 2.1339, 'LSTM_Model': 1.2437},
#  '100k': {'CNN_Model': 1.5291, 'LSTM_Model': 1.0081}}

# %%
accuracy_list
# Out:
# {'3k': {'CNN_Model': 55.5, 'LSTM_Model': 39.8},
#  '10k': {'CNN_Model': 58.3, 'LSTM_Model': 54.9},
#  '30k': {'CNN_Model': 61.6, 'LSTM_Model': 67.3},
#  '60k': {'CNN_Model': 59.0, 'LSTM_Model': 70.1},
#  '100k': {'CNN_Model': 61.6, 'LSTM_Model': 72.7}}

# %%
f1_list
# Out:
# {'3k': {'CNN_Model': 46.1, 'LSTM_Model': 33.8},
#  '10k': {'CNN_Model': 50.6, 'LSTM_Model': 46.6},
#  '30k': {'CNN_Model': 54.9, 'LSTM_Model': 60.8},
#  '60k': {'CNN_Model': 52.3, 'LSTM_Model': 62.8},
#  '100k': {'CNN_Model': 54.9, 'LSTM_Model': 66.2}}

# %%
x = loss_list.keys()
cnn_loss = [loss_list[i]['CNN_Model'] for i in x]
lstm_loss = [loss_list[i]['LSTM_Model'] for i in x]
cnn_acc = [accuracy_list[i]['CNN_Model'] for i in x]
lstm_acc = [accuracy_list[i]['LSTM_Model'] for i in x]
cnn_f1 = [f1_list[i]['CNN_Model'] for i in x]
lstm_f1 = [f1_list[i]['LSTM_Model'] for i in x]

plt.figure(figsize=(10, 3))
plt.subplot(1, 3, 1)
plt.plot(x, cnn_loss, label='CNN', color='darkorange', marker='o')
plt.plot(x, lstm_loss, label='LSTM', color='blue', marker='s')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1, 3, 2)
plt.plot(x, cnn_acc, label='CNN', color='darkorange', marker='o')
plt.plot(x, lstm_acc, label='LSTM', color='blue', marker='s')
plt.ylabel('Accuracy(%)')
# plt.legend()
plt.subplot(1, 3, 3)
plt.plot(x, cnn_f1, label='CNN', color='darkorange', marker='o')
plt.plot(x, lstm_f1, label='LSTM', color='blue', marker='s')
plt.ylabel('F1 score(%)')
# plt.legend()
plt.tight_layout()
plt.show()

# %%
# loss_list = {}
# f1_list = {}
# accuracy_list = {}
# for fname, models in model_list.items():
#     print(f'evaluate on dataset {fname}')
#     loss_list[fname] = {}
#     f1_list[fname] = {}
#     accuracy_list[fname] = {}
#     for model in models:
#         loss, f1, accuracy, name = pred(model, test_loader, loss_function, using_features=False)
#         print(f'{name} results: loss: {loss:.4f} ; accuracy: {accuracy:.4f} ; f1: {f1:.4f}')
#         loss_list[fname][name] = loss
#         f1_list[fname][name] = f1
#         accuracy_list[fname][name] = accuracy
