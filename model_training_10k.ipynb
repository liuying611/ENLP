# %% [markdown]
# ### Morden Neural Network: LSTM & CNN

# %%
from mordenNN import *
import pandas as pd
from sklearn.model_selection import train_test_split
from EDA import *
from sklearn.preprocessing import LabelEncoder
from torch.optim import AdamW

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# [nltk_data] Downloading package wordnet to /Users/yaoyao/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/yaoyao/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('./data/df_10_category_balance_60k_pca.csv')
le = LabelEncoder()
df['category'] = le.fit_transform(df['category'])
da = DataAnlysisPCA(df)
max_len, length_list = da.get_max_word_length(plot=False)
word_count_df, df_most_common, df_pca = da.get_most_common_words(plot=False)
word_count_df = pd.Series(word_count_df['count'].values, index=word_count_df['word'].values)
# Out:
# /Users/yaoyao/miniconda3/envs/tf/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#  Starting building CountMatrix of top 50 common words...
#
#  Starting PCA to find best component...
#
#  total most common words: 50
# Best Component that keep 90% info: 41
#
#  PCA: Starting reducing dimension...

# %%
train, test = train_test_split(df, test_size=0.2, random_state=42)
val, test = train_test_split(test, test_size=0.5, random_state=42)
print(f'Train set length: {len(train)} ; categories: {train["category"].nunique()}')
print(f'Val set length: {len(val)} ; categories: {val["category"].nunique()}')
print(f'Test set length: {len(test)} ; categories: {test["category"].nunique()}')
word2index, index2word = prepare_text_dict(word_count_df)

train_data = Data(train, word2index)
val_data = Data(val, word2index)
test_data = Data(test, word2index)

features_cols = df.columns.drop(['category', 'text', 'sa'])

label2encoding = dict(zip(le.classes_, le.transform(le.classes_)))
encoding2label = dict(zip(le.transform(le.classes_), le.classes_))
train_loader = DataLoader(train_data, batch_size=32, collate_fn=collate_fn_padded)
val_loader = DataLoader(val_data, batch_size=32, collate_fn=collate_fn_padded)
test_loader = DataLoader(test_data, batch_size=32, collate_fn=collate_fn_padded)
vector_size = 50
word2vec_embeddings = get_mapping_dict(df, word2index, vector_size= vector_size)
embedding_matrix = create_embedding_matrix( word2index, word2vec_embeddings, vector_size)
# Out:
# Train set length: 24000 ; categories: 10
# Val set length: 3000 ; categories: 10
# Test set length: 3000 ; categories: 10
#
# word2vec embeddings...
# word2vec embeddings found for our vocabs: 52 | missing: 0 ; 0.0%

# %%
vocab_size = len(word2index)
embedding_dim = 50
output_size = len(le.classes_)

hidden_size = 64
n_filters = 64
n_layers = 2
filter_sizes = [2, 3, 5, 7]
print('Size Of Vocab: ', vocab_size)


model_lstm = LSTM_Model(vocab_size, embedding_dim, hidden_size, n_layers, output_size)

model_cnn = CNN_Model(vocab_size, embedding_dim, hidden_size, n_filters, filter_sizes, output_size)
models = [model_cnn, model_lstm]

loss_function = nn.CrossEntropyLoss().to(device)
def count_parameters(model):
    # to know how many parametres a 'trained' model has  
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
for clf in models:
    print('----------------------')
    print('----------------------')
    print('model Name: ', type(clf).__name__) # print Model Name
    print(f'{type(clf).__name__} has {count_parameters(clf):,} trainable parameters') # print Model Total Parameters 
    clf = clf.to(device) # convert model to GPU memory for fast training
    # use flexible learning rate
    
    optimizer = AdamW(clf.parameters(), lr= 0.01, weight_decay=0.01) # assign AdamW as optimizer
    
    training_model(clf, optimizer, loss_function, train_loader, val_loader, epochs=100, using_features=False)
# Out:
# Size Of Vocab:  52
# ----------------------
# ----------------------
# model Name:  CNN_Model
# CNN_Model has 59,826 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.083 | acc: 27.9 | f1-score: 17.1) & Eval(loss: 2.1358 | acc: 24.1 | f1-score: 14.3)
#
# ----------------------
# ----------------------
# model Name:  LSTM_Model
# LSTM_Model has 70,386 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.0077 | acc: 29.5 | f1-score: 16.5) & Eval(loss: 2.0712 | acc: 24.9 | f1-score: 15.5)

# %% [markdown]
# #### LSTM

# %% [markdown]
# ##### Gridsearch

# %%
def plot_grid_search_score(score_list):
    loss_list = [tuple[0] for tuple in score_list.values()]
    acc_list = [tuple[1] for tuple in score_list.values()]
    f1_list = [tuple[2] for tuple in score_list.values()]

    eval_loss_list = [tuple[3] for tuple in score_list.values()]
    eval_acc_list = [tuple[4] for tuple in score_list.values()]
    eval_f1_list = [tuple[5] for tuple in score_list.values()]


    sns.set_style("whitegrid")
    plt.figure(figsize=(12, 6))
    plt.plot(score_list.keys(), loss_list, label='train_loss')
    plt.plot(score_list.keys(), eval_loss_list, label='eval_loss', linestyle='--')
    plt.plot(score_list.keys(), acc_list, label='train_acc')
    plt.plot(score_list.keys(), eval_acc_list, label='eval_acc', linestyle='--')
    plt.plot(score_list.keys(), f1_list, label='train_f1')
    plt.plot(score_list.keys(), eval_f1_list, label='eval_f1', linestyle='--')
    plt.xlabel('parameter index')
    plt.xticks(rotation=90)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# common variables for both models
vocab_size = len(word2index)
output_size = len(le.classes_)

# LSTM Model variables
#embedding_dim = 50
#hidden_size = 64
#n_layers = 2
param_grid = {
    'embedding_dim': [50, 100, 200],
    'hidden_size': [32, 64, 128],
    'n_layers': [2, 3, 4]
}
print('Size Of Vocab: ', vocab_size)
score_list = {}
def grid_search_LSTM(vocab_size, output_size, param_grid, train_loader, val_loader):
    embedding_dim = 0
    hidden_size = 0
    n_layers = 0
    for i in range(3):
        for j in range(3):
            for k in range(3):
                embedding_dim = param_grid['embedding_dim'][i]
                hidden_size = param_grid['hidden_size'][j]
                n_layers = param_grid['n_layers'][k]
                model = LSTM_Model(vocab_size = vocab_size, output_size = output_size, embedding_dim=embedding_dim, hidden_size=hidden_size, n_layers=n_layers)
                loss_function = nn.CrossEntropyLoss().to(device)
                model = model.to(device)
                print('----------------------')
                print('----------------------')
                print(f'embedding_dim: {embedding_dim} ; hidden_size: {hidden_size} ; n_layers: {n_layers}')
                optimizer = AdamW(model.parameters(), lr= 0.01, weight_decay=0.01) # assign AdamW as optimizer
                score_list[f'{i}{j}{k}'] = training_model(model, optimizer, loss_function, train_loader, val_loader, epochs=100, using_features=False)[2:]
                
    return score_list

score_list = grid_search_LSTM(vocab_size, output_size, param_grid, train_loader, val_loader)
plot_grid_search_score(score_list)
# Out:
# Size Of Vocab:  52
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 32 ; n_layers: 2
#
# Training Started...
# /Users/yaoyao/Desktop/CourseExercise/ENLP/mordenNN.py:276: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:264.)
#   features = torch.tensor(features, device=device, dtype=torch.float)
# BEST Epoch(1 | Train(loss: 2.1302 | acc: 23.2 | f1-score: 11.2) & Eval(loss: 2.1194 | acc: 26.4 | f1-score: 16.6)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 32 ; n_layers: 3
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1473 | acc: 22.9 | f1-score: 11.4) & Eval(loss: 2.1391 | acc: 24.9 | f1-score: 14.2)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 32 ; n_layers: 4
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1866 | acc: 20.2 | f1-score: 8.5) & Eval(loss: 2.165 | acc: 23.3 | f1-score: 11.2)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 64 ; n_layers: 2
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.0862 | acc: 26.4 | f1-score: 13.8) & Eval(loss: 2.08 | acc: 28.2 | f1-score: 16.4)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 64 ; n_layers: 3
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1425 | acc: 21.8 | f1-score: 9.9) & Eval(loss: 2.1407 | acc: 25.2 | f1-score: 12.2)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 64 ; n_layers: 4
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1938 | acc: 19.5 | f1-score: 8.0) & Eval(loss: 2.238 | acc: 17.5 | f1-score: 6.6)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 128 ; n_layers: 2
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.072 | acc: 26.1 | f1-score: 14.5) & Eval(loss: 2.1096 | acc: 27.6 | f1-score: 18.2)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 128 ; n_layers: 3
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1363 | acc: 21.9 | f1-score: 10.2) & Eval(loss: 2.1771 | acc: 24.0 | f1-score: 11.9)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 128 ; n_layers: 4
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.2243 | acc: 18.2 | f1-score: 6.4) & Eval(loss: 2.3042 | acc: 17.2 | f1-score: 8.3)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 32 ; n_layers: 2
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1003 | acc: 25.0 | f1-score: 12.8) & Eval(loss: 2.0744 | acc: 26.6 | f1-score: 15.3)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 32 ; n_layers: 3
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1643 | acc: 21.0 | f1-score: 9.0) & Eval(loss: 2.1823 | acc: 23.3 | f1-score: 11.1)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 32 ; n_layers: 4
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1644 | acc: 20.3 | f1-score: 8.8) & Eval(loss: 2.1872 | acc: 23.9 | f1-score: 12.4)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 64 ; n_layers: 2
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.0822 | acc: 26.2 | f1-score: 14.1) & Eval(loss: 2.0303 | acc: 29.2 | f1-score: 17.8)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 64 ; n_layers: 3
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1331 | acc: 22.2 | f1-score: 10.4) & Eval(loss: 2.1791 | acc: 23.2 | f1-score: 10.9)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 64 ; n_layers: 4
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1373 | acc: 23.7 | f1-score: 11.2) & Eval(loss: 2.1029 | acc: 27.7 | f1-score: 16.2)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 128 ; n_layers: 2
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.0696 | acc: 26.6 | f1-score: 15.1) & Eval(loss: 2.0616 | acc: 28.1 | f1-score: 17.3)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 128 ; n_layers: 3
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1436 | acc: 21.4 | f1-score: 10.4) & Eval(loss: 2.1931 | acc: 23.1 | f1-score: 11.4)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 128 ; n_layers: 4
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1779 | acc: 19.7 | f1-score: 8.8) & Eval(loss: 2.2095 | acc: 17.2 | f1-score: 9.9)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 32 ; n_layers: 2
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1223 | acc: 24.2 | f1-score: 11.7) & Eval(loss: 2.0875 | acc: 26.3 | f1-score: 15.4)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 32 ; n_layers: 3
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.124 | acc: 24.0 | f1-score: 11.7) & Eval(loss: 2.113 | acc: 25.6 | f1-score: 14.7)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 32 ; n_layers: 4
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1746 | acc: 20.2 | f1-score: 8.5) & Eval(loss: 2.2219 | acc: 20.5 | f1-score: 8.2)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 64 ; n_layers: 2
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.0955 | acc: 25.3 | f1-score: 13.2) & Eval(loss: 2.0677 | acc: 27.9 | f1-score: 16.5)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 64 ; n_layers: 3
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1385 | acc: 21.9 | f1-score: 10.0) & Eval(loss: 2.1829 | acc: 25.1 | f1-score: 13.3)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 64 ; n_layers: 4
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1646 | acc: 20.2 | f1-score: 8.8) & Eval(loss: 2.1863 | acc: 24.1 | f1-score: 12.0)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 128 ; n_layers: 2
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.0805 | acc: 26.8 | f1-score: 14.0) & Eval(loss: 2.0739 | acc: 27.8 | f1-score: 18.0)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 128 ; n_layers: 3
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.0925 | acc: 26.6 | f1-score: 14.1) & Eval(loss: 2.1421 | acc: 27.3 | f1-score: 17.0)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 128 ; n_layers: 4
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.187 | acc: 19.6 | f1-score: 7.9) & Eval(loss: 2.2521 | acc: 19.4 | f1-score: 9.7)

# %%
# use the best performed parameters to train the model
best_embedding_dim = 100
best_hidden_size = 64
best_n_layers = 2
print('Size Of Vocab: ', vocab_size)

model_lstm = LSTM_Model(vocab_size, best_embedding_dim, best_hidden_size, best_n_layers, output_size)
loss_function = nn.CrossEntropyLoss().to(device)
def count_parameters(model):
    # to know how many parametres a 'trained' model has  
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
model = model_lstm
print('----------------------')
print('----------------------')
print('model Name: ', type(model).__name__) # print Model Name
print(f'{type(model).__name__} has {count_parameters(model):} trainable parameters') # print Model Total Parameters 
model = model.to(device) # convert model to GPU memory for fast training
optimizer = AdamW(model.parameters(), lr= 0.001, weight_decay=0.01) # assign AdamW as optimizer

result = training_model(model, optimizer, loss_function, train_loader, val_loader, epochs=100, using_features=False)
# test on the best model
model = model.to(device)
loss, f1, accuracy, name = pred(model, test_loader, loss_function, using_features=False)
print(f'{name} with loss: {loss:.4f} ; accuracy: {accuracy:.4f} ; f1: {f1:.4f}')
# Out:
# Size Of Vocab:  52
# ----------------------
# ----------------------
# model Name:  LSTM_Model
# LSTM_Model has 85786 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1656 | acc: 20.3 | f1-score: 10.0) & Eval(loss: 2.0716 | acc: 25.6 | f1-score: 13.8)
#
# LSTM_Model with loss: 2.0619 ; accuracy: 22.9000 ; f1: 12.8000

# %% [markdown]
# #### CNN

# %% [markdown]
# ##### Gridsearch

# %%
# common variables for both models
vocab_size = len(word2index)
output_size = len(le.classes_)

# LSTM Model variables
#embedding_dim = 50
#hidden_size = 64
#n_layers = 2
param_grid = {
    'embedding_dim': [50, 100, 200],
    'hidden_size': [32, 64, 128],
    'n_filters': [32, 64, 128]
}
print('Size Of Vocab: ', vocab_size)
score_list = {}
def grid_search_CNN(vocab_size, output_size, param_grid, train_loader, val_loader):
    embedding_dim = 0
    hidden_size = 0
    n_layers = 0
    for i in range(3):
        for j in range(3):
            for k in range(3):
                embedding_dim = param_grid['embedding_dim'][i]
                hidden_size = param_grid['hidden_size'][j]
                n_filters = param_grid['n_filters'][k]
                filter_sizes = [2, 3, 5, 7]
                model = CNN_Model(vocab_size, embedding_dim, hidden_size, n_filters, filter_sizes, output_size)
                loss_function = nn.CrossEntropyLoss().to(device)
                model = model.to(device)
                print('----------------------')
                print('----------------------')
                print(f'embedding_dim: {embedding_dim} ; hidden_size: {hidden_size} ; n_filters: {n_filters}')
                optimizer = AdamW(model.parameters(), lr= 0.01, weight_decay=0.01) # assign AdamW as optimizer
                score_list[f'{i}{j}{k}'] = training_model(model, optimizer, loss_function, train_loader, val_loader, epochs=100, using_features=False)[2:]
                
    return score_list

score_list = grid_search_CNN(vocab_size, output_size, param_grid, train_loader, val_loader)
plot_grid_search_score(score_list)
# Out:
# Size Of Vocab:  52
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 32 ; n_filters: 32
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.139 | acc: 26.0 | f1-score: 16.7) & Eval(loss: 2.0792 | acc: 25.3 | f1-score: 16.7)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 32 ; n_filters: 64
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.2116 | acc: 25.0 | f1-score: 16.3) & Eval(loss: 2.0732 | acc: 27.3 | f1-score: 18.1)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 32 ; n_filters: 128
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.2429 | acc: 26.0 | f1-score: 17.2) & Eval(loss: 2.1191 | acc: 23.4 | f1-score: 15.4)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 64 ; n_filters: 32
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1292 | acc: 26.1 | f1-score: 16.9) & Eval(loss: 2.0509 | acc: 27.6 | f1-score: 18.4)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 64 ; n_filters: 64
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.191 | acc: 26.0 | f1-score: 17.2) & Eval(loss: 2.072 | acc: 26.2 | f1-score: 17.8)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 64 ; n_filters: 128
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.2646 | acc: 25.0 | f1-score: 16.2) & Eval(loss: 2.0782 | acc: 28.2 | f1-score: 19.0)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 128 ; n_filters: 32
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1445 | acc: 25.5 | f1-score: 16.4) & Eval(loss: 2.0109 | acc: 29.5 | f1-score: 20.3)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 128 ; n_filters: 64
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.2121 | acc: 25.2 | f1-score: 16.0) & Eval(loss: 2.098 | acc: 27.1 | f1-score: 17.8)
#
# ----------------------
# ----------------------
# embedding_dim: 50 ; hidden_size: 128 ; n_filters: 128
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.3169 | acc: 25.3 | f1-score: 16.8) & Eval(loss: 2.0897 | acc: 26.2 | f1-score: 17.6)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 32 ; n_filters: 32
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1829 | acc: 25.5 | f1-score: 15.6) & Eval(loss: 2.1035 | acc: 25.0 | f1-score: 17.1)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 32 ; n_filters: 64
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.3247 | acc: 24.6 | f1-score: 16.1) & Eval(loss: 2.1263 | acc: 24.4 | f1-score: 15.7)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 32 ; n_filters: 128
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.5457 | acc: 25.0 | f1-score: 14.9) & Eval(loss: 2.1408 | acc: 22.8 | f1-score: 13.4)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 64 ; n_filters: 32
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.2092 | acc: 25.1 | f1-score: 16.0) & Eval(loss: 2.1046 | acc: 25.3 | f1-score: 16.8)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 64 ; n_filters: 64
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.3023 | acc: 24.2 | f1-score: 15.3) & Eval(loss: 2.1778 | acc: 20.5 | f1-score: 11.5)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 64 ; n_filters: 128
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.544 | acc: 24.5 | f1-score: 15.8) & Eval(loss: 2.0818 | acc: 27.8 | f1-score: 18.6)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 128 ; n_filters: 32
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1922 | acc: 24.5 | f1-score: 15.5) & Eval(loss: 2.1118 | acc: 24.6 | f1-score: 16.1)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 128 ; n_filters: 64
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.2952 | acc: 24.8 | f1-score: 15.7) & Eval(loss: 2.1393 | acc: 22.5 | f1-score: 12.9)
#
# ----------------------
# ----------------------
# embedding_dim: 100 ; hidden_size: 128 ; n_filters: 128
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.6757 | acc: 24.4 | f1-score: 16.1) & Eval(loss: 2.1045 | acc: 26.9 | f1-score: 18.2)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 32 ; n_filters: 32
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.3025 | acc: 23.9 | f1-score: 14.9) & Eval(loss: 2.1391 | acc: 23.0 | f1-score: 14.0)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 32 ; n_filters: 64
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.5784 | acc: 23.8 | f1-score: 14.6) & Eval(loss: 2.0877 | acc: 26.5 | f1-score: 17.1)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 32 ; n_filters: 128
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 3.2644 | acc: 23.2 | f1-score: 14.9) & Eval(loss: 2.1579 | acc: 21.6 | f1-score: 11.0)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 64 ; n_filters: 32
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.3588 | acc: 23.4 | f1-score: 13.9) & Eval(loss: 2.1477 | acc: 23.7 | f1-score: 14.2)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 64 ; n_filters: 64
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.5245 | acc: 24.0 | f1-score: 14.5) & Eval(loss: 2.1705 | acc: 20.9 | f1-score: 11.4)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 64 ; n_filters: 128
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 3.134 | acc: 22.8 | f1-score: 14.2) & Eval(loss: 2.1665 | acc: 20.5 | f1-score: 10.9)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 128 ; n_filters: 32
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.4166 | acc: 22.9 | f1-score: 13.9) & Eval(loss: 2.1615 | acc: 22.2 | f1-score: 12.0)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 128 ; n_filters: 64
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.6035 | acc: 23.7 | f1-score: 14.9) & Eval(loss: 2.2177 | acc: 23.7 | f1-score: 13.8)
#
# ----------------------
# ----------------------
# embedding_dim: 200 ; hidden_size: 128 ; n_filters: 128
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 3.5581 | acc: 23.2 | f1-score: 14.3) & Eval(loss: 2.1484 | acc: 24.1 | f1-score: 13.8)

# %% [markdown]
# Notice: pick the best parameters from above result

# %%
# CNN Model variables
best_embedding_dim = 50
best_hidden_size = 64
best_n_filters = 32
filter_sizes = [2, 3, 5, 7]
model_cnn = CNN_Model(vocab_size, best_embedding_dim, best_hidden_size, best_n_filters, filter_sizes, output_size)
models = [model_cnn, model_lstm]
loss_function = nn.CrossEntropyLoss().to(device)
def count_parameters(model):
    # to know how many parametres a 'trained' model has  
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
model = model_cnn
print('----------------------')
print('----------------------')
print('model Name: ', type(model).__name__) # print Model Name
print(f'{type(model).__name__} has {count_parameters(model):,} trainable parameters') # print Model Total Parameters 
clmodelf = model.to(device) # convert model to GPU memory for fast training
optimizer = AdamW(model.parameters(), lr= 0.01, weight_decay=0.01) # assign AdamW as optimizer

result = training_model(model, optimizer, loss_function, train_loader, val_loader, epochs=100, using_features=False)

# test on the best model
model = model.to(device)
loss, f1, accuracy, name = pred(model, test_loader, loss_function, using_features=False)
print(f'{name} with loss: {loss:.4f} ; accuracy: {accuracy:.4f} ; f1: {f1:.4f}')
# Out:
# ----------------------
# ----------------------
# model Name:  CNN_Model
# CNN_Model has 31,218 trainable parameters
#
# Training Started...
#
# BEST Epoch(1 | Train(loss: 2.1447 | acc: 26.3 | f1-score: 17.1) & Eval(loss: 2.1037 | acc: 24.1 | f1-score: 15.5)
#
# CNN_Model with loss: 2.1205 ; accuracy: 21.0000 ; f1: 14.1000
